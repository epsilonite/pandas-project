# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 import requests
#       4 import pandas as pd
# ----> 5 from config import api_key
#
# ImportError: cannot import name 'api_key' from 'config' (C:\repos\pandas-project\California Wildfire Seasonality\config.py)

# %%
# Save config information.
url = "https://data.ca.gov/api/3/action/datastore_search?resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991&"

# Build partial query URL
query_url = f"{url}&limit=284"
response = requests.get(query_url).json()
response
# Out:
# {'help': 'https://data.ca.gov/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 284,
#   'records_format': 'objects',
#   'resource_id': 'd73ee828-c2c6-485c-91dc-c26bd9ce3991',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'OBJECTID': '1',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SKU',
#     'Fire Name': 'WHITWORTH',
#     'Local Incident Number': '00004808',
#     'Alarm Date': '6/17/2023 12:00:00 AM',
#     'Containment Date': '6/17/2023 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.729125',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{7985848C-0AC2-4BA4-8F0E-29F778652E61}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '41407.83984375',
#     'Shape__Length': '1247.16603398886'},
#    {'_id': 2,
#     'OBJECTID': '2',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'BTU',
#     'Fire Name': 'KAISER',
#     'Local Incident Number': '00010225',
#     'Alarm Date': '6/2/2023 12:00:00 AM',
#     'Containment Date': '6/2/2023 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '13.60238',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{43EBCC88-B3AC-48EB-8EF5-417FE0939CCF}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '93455.87890625',
#     'Shape__Length': '1285.51454971661'},
#    {'_id': 3,
#     'OBJECTID': '3',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'JACKSON',
#     'Local Incident Number': '00017640',
#     'Alarm Date': '7/1/2023 12:00:00 AM',
#     'Containment Date': '7/2/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '27.81446',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{B64E1355-BF1D-441A-95D0-BC1FBB93483B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '183028.5',
#     'Shape__Length': '2697.58742917456'},
#    {'_id': 4,
#     'OBJECTID': '4',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'CARBON',
#     'Local Incident Number': '00018821',
#     'Alarm Date': '7/11/2023 12:00:00 AM',
#     'Containment Date': '7/11/2023 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '58.76023',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{CB41DB0A-E4B1-489D-A4EA-738F2CD6DB3B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '388221.953125',
#     'Shape__Length': '2548.73877855158'},
#    {'_id': 5,
#     'OBJECTID': '5',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'LIBERTY',
#     'Local Incident Number': '00018876',
#     'Alarm Date': '7/11/2023 12:00:00 AM',
#     'Containment Date': '7/12/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '70.979',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{F83F70A4-07A7-40B8-BD51-10CCC1C30D63}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '466456.0078125',
#     'Shape__Length': '5106.93652582734'},
#    {'_id': 6,
#     'OBJECTID': '6',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'CLAY',
#     'Local Incident Number': '00016263',
#     'Alarm Date': '6/18/2023 12:00:00 AM',
#     'Containment Date': '6/18/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '28.63791',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{428149C3-A93B-4B17-A22B-60D73AC7D4D2}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '188516.984375',
#     'Shape__Length': '1941.50983446427'},
#    {'_id': 7,
#     'OBJECTID': '7',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BEU',
#     'Fire Name': 'PAICINES',
#     'Local Incident Number': '00004105',
#     'Alarm Date': '7/13/2023 12:00:00 AM',
#     'Containment Date': '7/13/2023 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '13.59313',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{D8809C1A-6991-4432-B9FA-DA4F3D78AB49}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '85835.91796875',
#     'Shape__Length': '1776.4387595018'},
#    {'_id': 8,
#     'OBJECTID': '8',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BEU',
#     'Fire Name': 'VINEYARD',
#     'Local Incident Number': '00004022',
#     'Alarm Date': '7/9/2023 12:00:00 AM',
#     'Containment Date': '7/10/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '391.3749',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{FF1BDD2B-496B-4193-B641-37802DA7E8A7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '2412533.5546875',
#     'Shape__Length': '10733.8123075036'},
#    {'_id': 9,
#     'OBJECTID': '9',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BEU',
#     'Fire Name': 'SLACKS',
#     'Local Incident Number': '00004156',
#     'Alarm Date': '7/15/2023 12:00:00 AM',
#     'Containment Date': '7/17/2023 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '40.41796',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8C3A9ADB-EB11-4000-B21A-6261BD8A74D4}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '249660.2734375',
#     'Shape__Length': '2407.16695678565'},
#    {'_id': 10,
#     'OBJECTID': '10',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BEU',
#     'Fire Name': 'IDRIA',
#     'Local Incident Number': '00004234',
#     'Alarm Date': '7/19/2023 12:00:00 AM',
#     'Containment Date': '7/19/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '296.6445',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{4D7CCAEE-1845-4A23-A09B-D33BEB748EEE}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '1860464.30078125',
#     'Shape__Length': '10225.7742396832'},
#    {'_id': 11,
#     'OBJECTID': '11',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SHU',
#     'Fire Name': 'WONDER',
#     'Local Incident Number': '00008060',
#     'Alarm Date': '7/24/2023 12:00:00 AM',
#     'Containment Date': '7/28/2023 12:00:00 AM',
#     'Cause': '6',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '161.8137',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{EE0AD4B3-4F0A-4F46-93A8-6FC930B7DF69}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '1141858.58984375',
#     'Shape__Length': '7184.88555633728'},
#    {'_id': 12,
#     'OBJECTID': '12',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SHU',
#     'Fire Name': 'PINE',
#     'Local Incident Number': '00006202',
#     'Alarm Date': '6/15/2023 12:00:00 AM',
#     'Containment Date': '6/15/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.91801',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{5713E1F7-ABE7-4DEA-B04D-1EF87247B468}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '83320.984375',
#     'Shape__Length': '1388.85090723164'},
#    {'_id': 13,
#     'OBJECTID': '13',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SHU',
#     'Fire Name': 'OLIVE',
#     'Local Incident Number': '00008264',
#     'Alarm Date': '7/29/2023 12:00:00 AM',
#     'Containment Date': '7/29/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '20.67',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{7607B6CD-C0B3-40F8-BB68-2CEED3B441AB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '143460.0078125',
#     'Shape__Length': '2544.54186805971'},
#    {'_id': 14,
#     'OBJECTID': '14',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BTU',
#     'Fire Name': 'TURKEY',
#     'Local Incident Number': '00014148',
#     'Alarm Date': '7/26/2023 12:00:00 AM',
#     'Containment Date': '7/31/2023 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '52.17383',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{203888E8-5D22-4C40-9349-825708637CDC}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '354598.3046875',
#     'Shape__Length': '3866.55622041301'},
#    {'_id': 15,
#     'OBJECTID': '15',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'BTU',
#     'Fire Name': 'VIRGINIA',
#     'Local Incident Number': '00011549',
#     'Alarm Date': '6/21/2023 12:00:00 AM',
#     'Containment Date': '6/21/2023 12:00:00 AM',
#     'Cause': '4',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.07201',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{2381B3FE-68C0-4664-AA2A-CF830D6833B5}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '68524.96875',
#     'Shape__Length': '1209.30553410994'},
#    {'_id': 16,
#     'OBJECTID': '16',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'RRU',
#     'Fire Name': 'RABBIT',
#     'Local Incident Number': '00102458',
#     'Alarm Date': '7/14/2023 12:00:00 AM',
#     'Containment Date': '7/23/2023 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '8354.776',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{04F24B12-E13F-4C7E-80AF-C8AA1A4C8FAB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '49193097.9453125',
#     'Shape__Length': '47639.7437077098'},
#    {'_id': 17,
#     'OBJECTID': '17',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'RRU',
#     'Fire Name': 'HIGHLAND',
#     'Local Incident Number': '00102435',
#     'Alarm Date': '7/14/2023 12:00:00 AM',
#     'Containment Date': '7/23/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '104.0207',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{CDD1E559-3BBE-4680-A933-9694DD48BEA4}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '612635.0234375',
#     'Shape__Length': '3915.57257152357'},
#    {'_id': 18,
#     'OBJECTID': '18',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'RRU',
#     'Fire Name': 'RECHE',
#     'Local Incident Number': '00102379',
#     'Alarm Date': '7/14/2023 12:00:00 AM',
#     'Containment Date': '7/23/2023 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '435.684',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '2570257.99609375',
#     'Shape__Length': '8565.27516599609'},
#    {'_id': 19,
#     'OBJECTID': '19',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'RRU',
#     'Fire Name': 'GAVILAN',
#     'Local Incident Number': '00103039',
#     'Alarm Date': '7/15/2023 12:00:00 AM',
#     'Containment Date': '7/23/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '334.5828',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{2EB6C428-B6F4-486F-9CA3-492F45EFBB30}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '1966205.47265625',
#     'Shape__Length': '7959.66657521688'},
#    {'_id': 20,
#     'OBJECTID': '20',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'RRU',
#     'Fire Name': 'RAMONA',
#     'Local Incident Number': '00074508',
#     'Alarm Date': '5/22/2023 12:00:00 AM',
#     'Containment Date': '5/26/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '337.9316',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{92634986-F462-4277-ACAE-0062553E530D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '1986003.47265625',
#     'Shape__Length': '7664.10111785175'},
#    {'_id': 21,
#     'OBJECTID': '21',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'BTU',
#     'Fire Name': 'CEMETERY',
#     'Local Incident Number': '00015186',
#     'Alarm Date': '8/9/2023 12:00:00 AM',
#     'Containment Date': '8/9/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '74.10231',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{768B16BB-3B0F-450E-B61B-8263D9B3751F}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '502589.3828125',
#     'Shape__Length': '3982.26722140786'},
#    {'_id': 22,
#     'OBJECTID': '22',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MEU',
#     'Fire Name': '1-10',
#     'Local Incident Number': '00009853',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '8/18/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '56.87772',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8EF2DA82-93EE-401C-BD4E-6E380CC7F09E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '392924.71875',
#     'Shape__Length': '3555.76506096679'},
#    {'_id': 23,
#     'OBJECTID': '23',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'BTU',
#     'Fire Name': 'CANA',
#     'Local Incident Number': '00017710',
#     'Alarm Date': '9/16/2023 12:00:00 AM',
#     'Containment Date': '9/16/2023 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '19.28816',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E5A728D8-40AF-47FA-8965-293D0877A8CE}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '132527.5546875',
#     'Shape__Length': '1574.848975552'},
#    {'_id': 24,
#     'OBJECTID': '24',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'MISTY',
#     'Local Incident Number': '00028286',
#     'Alarm Date': '10/14/2023 12:00:00 AM',
#     'Containment Date': '10/14/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.7',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{C0A92C79-B606-4FE6-B750-5C29B3D408C4}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '77082.015625',
#     'Shape__Length': '1326.14840721991'},
#    {'_id': 25,
#     'OBJECTID': '25',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'RRU',
#     'Fire Name': 'HIGHLAND',
#     'Local Incident Number': '00160976',
#     'Alarm Date': '10/30/2023 12:00:00 AM',
#     'Containment Date': '11/8/2023 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2487',
#     'Comments': 'Auto-generated by EGP-IRWIN',
#     'Complex Name': None,
#     'IRWIN ID': '{A81913DF-822A-4ADB-A61F-A3B07B21FFB4}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '14121208.0507813',
#     'Shape__Length': '47327.1125758144'},
#    {'_id': 26,
#     'OBJECTID': '26',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'PLYMOUTH',
#     'Local Incident Number': '00030204',
#     'Alarm Date': '11/2/2023 12:00:00 AM',
#     'Containment Date': '11/2/2023 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.1',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{7A1560D1-88C1-4935-B99B-81AEDE5C298E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '71774.98046875',
#     'Shape__Length': '1248.54278186756'},
#    {'_id': 27,
#     'OBJECTID': '27',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BTU',
#     'Fire Name': 'WALL',
#     'Local Incident Number': '00021557',
#     'Alarm Date': '11/12/2023 12:00:00 AM',
#     'Containment Date': '11/12/2023 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.12262',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{B66D7631-2871-4981-BBCA-19A8C62F27FF}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '75606.7890625',
#     'Shape__Length': '1183.889292658'},
#    {'_id': 28,
#     'OBJECTID': '28',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'HOSTLY',
#     'Local Incident Number': '23-19678',
#     'Alarm Date': '5/1/2023 12:00:00 AM',
#     'Containment Date': '5/1/2023 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '83.71268',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A792B00B-F8C7-49A6-AF59-9A4CF38266D7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '512475.94921875',
#     'Shape__Length': '3523.40996548146'},
#    {'_id': 29,
#     'OBJECTID': '29',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ADOBE',
#     'Local Incident Number': '23-20044',
#     'Alarm Date': '5/3/2023 12:00:00 AM',
#     'Containment Date': '5/3/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.948729',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '36450.41796875',
#     'Shape__Length': '1312.57107632531'},
#    {'_id': 30,
#     'OBJECTID': '30',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'LAZY',
#     'Local Incident Number': '23-21128',
#     'Alarm Date': '5/10/2023 12:00:00 AM',
#     'Containment Date': '5/10/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3.267727',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '19948.7890625',
#     'Shape__Length': '742.667896509371'},
#    {'_id': 31,
#     'OBJECTID': '31',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BITTER',
#     'Local Incident Number': '23-21544',
#     'Alarm Date': '5/12/2023 12:00:00 AM',
#     'Containment Date': '5/12/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '225.6406',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{DA4CBDE1-2343-4C1C-9510-8D2DE169B7CD}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '1383222.34765625',
#     'Shape__Length': '5326.45543821856'},
#    {'_id': 32,
#     'OBJECTID': '32',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'LAVENDER ',
#     'Local Incident Number': '23-21875',
#     'Alarm Date': '5/14/2023 12:00:00 AM',
#     'Containment Date': '5/14/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '14.74279',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{9C62D925-2E90-4E1D-894C-D9B42BDE3374}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '90465.5625',
#     'Shape__Length': '1800.28339730919'},
#    {'_id': 33,
#     'OBJECTID': '33',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'KRN',
#     'Fire Name': 'POND',
#     'Local Incident Number': '23-22631',
#     'Alarm Date': '5/18/2023 12:00:00 AM',
#     'Containment Date': '5/18/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '6.763345',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '44627.17578125',
#     'Shape__Length': '1060.99837142796'},
#    {'_id': 34,
#     'OBJECTID': '34',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ELK',
#     'Local Incident Number': '23-23270',
#     'Alarm Date': '5/21/2023 12:00:00 AM',
#     'Containment Date': '5/21/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '9.687215',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{42200379-0E06-45C6-9088-08A4A864A1C3}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '58624.11328125',
#     'Shape__Length': '1374.36226100426'},
#    {'_id': 35,
#     'OBJECTID': '35',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TOLL',
#     'Local Incident Number': '23-23490',
#     'Alarm Date': '5/22/2023 12:00:00 AM',
#     'Containment Date': '5/22/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '6.860587',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{AD33BA43-3D1A-4058-ABDB-190663094691}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '41750.76171875',
#     'Shape__Length': '1105.91052052054'},
#    {'_id': 36,
#     'OBJECTID': '36',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'POINT',
#     'Local Incident Number': '23-25671',
#     'Alarm Date': '6/4/2023 12:00:00 AM',
#     'Containment Date': '6/4/2023 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.915308',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{15B30FD7-E1B9-43FE-9AEA-47971297B610}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '29805.7109375',
#     'Shape__Length': '907.303007096636'},
#    {'_id': 37,
#     'OBJECTID': '37',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'PENTLAND',
#     'Local Incident Number': '23-25892',
#     'Alarm Date': '6/5/2023 12:00:00 AM',
#     'Containment Date': '6/6/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '83.47556',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E7F412BC-CF01-4554-ABA6-CEF885F1C103}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '504927.51171875',
#     'Shape__Length': '4146.01597875623'},
#    {'_id': 38,
#     'OBJECTID': '38',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'LITTLE',
#     'Local Incident Number': '23-26311',
#     'Alarm Date': '6/8/2023 12:00:00 AM',
#     'Containment Date': '6/8/2023 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '59.26785',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{714280F7-556F-4D9C-87E5-DA30D20A82D1}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '363380.9921875',
#     'Shape__Length': '3161.21385528543'},
#    {'_id': 39,
#     'OBJECTID': '39',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ELK',
#     'Local Incident Number': '23-27131',
#     'Alarm Date': '6/13/2023 12:00:00 AM',
#     'Containment Date': '6/13/2023 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.666053',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{0960091D-3CA7-4DBF-B15D-2F26832188F7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '34513.80078125',
#     'Shape__Length': '1180.02780027584'},
#    {'_id': 40,
#     'OBJECTID': '40',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TANK',
#     'Local Incident Number': '23-28282',
#     'Alarm Date': '6/20/2023 12:00:00 AM',
#     'Containment Date': '6/21/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.777378',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{661E2ADE-9A60-4743-9FFF-52EFB2E700FB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '35535.09375',
#     'Shape__Length': '1446.9448978274'},
#    {'_id': 41,
#     'OBJECTID': '41',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'FAMOSO',
#     'Local Incident Number': '23-28727',
#     'Alarm Date': '6/23/2023 12:00:00 AM',
#     'Containment Date': '6/23/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '6.419109',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '39402.58203125',
#     'Shape__Length': '773.845044652949'},
#    {'_id': 42,
#     'OBJECTID': '42',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'LAST',
#     'Local Incident Number': '23-28896',
#     'Alarm Date': '6/24/2023 12:00:00 AM',
#     'Containment Date': '6/24/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3.334712',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A2E2ED4D-ED33-4AEF-9532-40647417D2AC}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '20361.14453125',
#     'Shape__Length': '646.584897570341'},
#    {'_id': 43,
#     'OBJECTID': '43',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'POST',
#     'Local Incident Number': '23-29421',
#     'Alarm Date': '6/27/2023 12:00:00 AM',
#     'Containment Date': '6/27/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.966745',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{946A8CB2-4F4E-4BB2-B2DE-E8AB99431480}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '36596.77734375',
#     'Shape__Length': '1362.92193236612'},
#    {'_id': 44,
#     'OBJECTID': '44',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'WATER',
#     'Local Incident Number': '23-29476',
#     'Alarm Date': '6/27/2023 12:00:00 AM',
#     'Containment Date': '6/27/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7.961721',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{7AB6162A-8A5E-4CB1-B31F-294D0FE55022}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '48856.96875',
#     'Shape__Length': '1201.87791796314'},
#    {'_id': 45,
#     'OBJECTID': '45',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'CHAMPAGNE',
#     'Local Incident Number': '23-29961',
#     'Alarm Date': '6/30/2023 12:00:00 AM',
#     'Containment Date': '6/30/2023 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '107.8487',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{87717210-BEED-4214-945C-3339EA5B6A47}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '651052.49609375',
#     'Shape__Length': '4648.68537232396'},
#    {'_id': 46,
#     'OBJECTID': '46',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TRUCK',
#     'Local Incident Number': '23-30046',
#     'Alarm Date': '6/30/2023 12:00:00 AM',
#     'Containment Date': '7/1/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '17.15697',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E3765817-840C-4B2C-820D-03A62C5BC5D8}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '103697.05078125',
#     'Shape__Length': '2221.2211032266'},
#    {'_id': 47,
#     'OBJECTID': '47',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ROUND',
#     'Local Incident Number': '23-30473',
#     'Alarm Date': '7/3/2023 12:00:00 AM',
#     'Containment Date': '7/3/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '536.0197',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{B4242042-2EFE-435F-A36A-6B59D7A2024A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '3290774.2578125',
#     'Shape__Length': '11616.3652403161'},
#    {'_id': 48,
#     'OBJECTID': '48',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'CANYON',
#     'Local Incident Number': '23-30325',
#     'Alarm Date': '7/2/2023 12:00:00 AM',
#     'Containment Date': '7/3/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '9.05986',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{04116A59-A1EF-4D62-8C07-D5F7484601C3}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '54912.9453125',
#     'Shape__Length': '1875.04816244704'},
#    {'_id': 49,
#     'OBJECTID': '49',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'SOUTH 2',
#     'Local Incident Number': '23-30565',
#     'Alarm Date': '7/3/2023 12:00:00 AM',
#     'Containment Date': '7/3/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '9.613276',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{EA3AF6CE-6390-462E-9905-5C95DAD0CB17}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '67641.21484375',
#     'Shape__Length': '1438.10278837926'},
#    {'_id': 50,
#     'OBJECTID': '50',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TREE',
#     'Local Incident Number': '23-30723',
#     'Alarm Date': '7/4/2023 12:00:00 AM',
#     'Containment Date': '7/4/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '6.170191',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{952FD679-0E1D-405D-B289-62F5AE6675B8}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '37428.29296875',
#     'Shape__Length': '1100.11406446195'},
#    {'_id': 51,
#     'OBJECTID': '51',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BAKER',
#     'Local Incident Number': '23-32167',
#     'Alarm Date': '7/11/2023 12:00:00 AM',
#     'Containment Date': '7/11/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3.72376',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{C6901541-B7ED-428F-B109-75066492826A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '22675.671875',
#     'Shape__Length': '1174.85848737343'},
#    {'_id': 52,
#     'OBJECTID': '52',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'MID',
#     'Local Incident Number': '23-32474',
#     'Alarm Date': '7/13/2023 12:00:00 AM',
#     'Containment Date': '7/13/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.990486',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{EC3D71E4-55C4-4566-B195-F402B582523B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '30309.01171875',
#     'Shape__Length': '777.184071121593'},
#    {'_id': 53,
#     'OBJECTID': '53',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'DISTRICT',
#     'Local Incident Number': '23-31430',
#     'Alarm Date': '7/7/2023 12:00:00 AM',
#     'Containment Date': '7/12/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1043.665',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{EA00B1B4-5871-4C87-AB80-9B68D5098CD0}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '6292144.94140625',
#     'Shape__Length': '12913.9059085782'},
#    {'_id': 54,
#     'OBJECTID': '54',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BODFISH',
#     'Local Incident Number': '23-33592',
#     'Alarm Date': '7/19/2023 12:00:00 AM',
#     'Containment Date': '7/20/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '52.75753',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{BC93D908-33C6-4BF5-BCB8-5177FE74CE83}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '321188.984375',
#     'Shape__Length': '2453.60466606071'},
#    {'_id': 55,
#     'OBJECTID': '55',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'SCODIE',
#     'Local Incident Number': '23-35185',
#     'Alarm Date': '7/28/2023 12:00:00 AM',
#     'Containment Date': '7/31/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '20.61374',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A10277F3-E477-4299-8F4D-949B40FC1AAE}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '126800.3203125',
#     'Shape__Length': '4049.18938777411'},
#    {'_id': 56,
#     'OBJECTID': '56',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BEALE',
#     'Local Incident Number': '23-35614',
#     'Alarm Date': '7/31/2023 12:00:00 AM',
#     'Containment Date': '8/1/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '60.6251',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{3D3FDB10-B268-4392-8947-1999CAF57F0C}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '368792.39453125',
#     'Shape__Length': '3734.17974082288'},
#    {'_id': 57,
#     'OBJECTID': '57',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'HABERKERN',
#     'Local Incident Number': '23-35677',
#     'Alarm Date': '7/31/2023 12:00:00 AM',
#     'Containment Date': '8/1/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '34.74714',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{40701B4A-C535-4B6A-936E-8AFE71047C03}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '209238.98828125',
#     'Shape__Length': '3222.64980333255'},
#    {'_id': 58,
#     'OBJECTID': '58',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'COMANCHE',
#     'Local Incident Number': '23-35813',
#     'Alarm Date': '8/1/2023 12:00:00 AM',
#     'Containment Date': '8/1/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.387525',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '26755.98828125',
#     'Shape__Length': '786.570330819241'},
#    {'_id': 59,
#     'OBJECTID': '59',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'EAST',
#     'Local Incident Number': '23-35760',
#     'Alarm Date': '8/1/2023 12:00:00 AM',
#     'Containment Date': '8/1/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1291.166',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E3496E18-73E9-4C83-BA88-2A0805CC469E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '7899533.1953125',
#     'Shape__Length': '15390.5216597692'},
#    {'_id': 60,
#     'OBJECTID': '60',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'EDMONSTON',
#     'Local Incident Number': '23-36091',
#     'Alarm Date': '8/3/2023 12:00:00 AM',
#     'Containment Date': '8/4/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '14.59014',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{3BDFED3A-E5DA-4D4C-84CE-765472D01A87}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '88044.421875',
#     'Shape__Length': '1789.61277467236'},
#    {'_id': 61,
#     'OBJECTID': '61',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ALMOND',
#     'Local Incident Number': '23-36511',
#     'Alarm Date': '8/6/2023 12:00:00 AM',
#     'Containment Date': '8/7/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5228.871',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8BF47465-2934-439A-B5D2-36047256714F}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '32043957.1210938',
#     'Shape__Length': '45656.0660909036'},
#    {'_id': 62,
#     'OBJECTID': '62',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BOULEVARD',
#     'Local Incident Number': '23-36217',
#     'Alarm Date': '8/4/2023 12:00:00 AM',
#     'Containment Date': '8/7/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '89.46474',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{5C095992-285B-4E6C-BECE-98F8C8352C18}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '542043.421875',
#     'Shape__Length': '8956.07928963521'},
#    {'_id': 63,
#     'OBJECTID': '63',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BRITE',
#     'Local Incident Number': '23-37066',
#     'Alarm Date': '8/9/2023 12:00:00 AM',
#     'Containment Date': '8/9/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3.816716',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{C6299ACC-E286-46A4-8392-EDCC4AFF337A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '23131.67578125',
#     'Shape__Length': '712.314840154778'},
#    {'_id': 64,
#     'OBJECTID': '64',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'GENERAL',
#     'Local Incident Number': '23-37712',
#     'Alarm Date': '8/13/2023 12:00:00 AM',
#     'Containment Date': '8/13/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '16.05068',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{6D4E368F-7B30-4316-9CB2-077EFA6DD14B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '97481.0390625',
#     'Shape__Length': '1702.3947196682'},
#    {'_id': 65,
#     'OBJECTID': '65',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TROTTER',
#     'Local Incident Number': '23-37821',
#     'Alarm Date': '8/14/2023 12:00:00 AM',
#     'Containment Date': '8/17/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '52.54716',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{5C9F8E96-A816-4A3C-9D0B-E2E06DA19D88}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '318702.40234375',
#     'Shape__Length': '4868.13291235762'},
#    {'_id': 66,
#     'OBJECTID': '66',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'GROVE',
#     'Local Incident Number': '23-37846',
#     'Alarm Date': '8/14/2023 12:00:00 AM',
#     'Containment Date': '8/14/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.713907',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E778E8BA-2671-4F47-8EFE-EF943B989AA7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '28567.82421875',
#     'Shape__Length': '1609.3463258167'},
#    {'_id': 67,
#     'OBJECTID': '67',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BLACKWELL',
#     'Local Incident Number': '23-38706',
#     'Alarm Date': '8/19/2023 12:00:00 AM',
#     'Containment Date': '8/19/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '34.64903',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '212358.31640625',
#     'Shape__Length': '2262.75029492936'},
#    {'_id': 68,
#     'OBJECTID': '68',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'SEMI',
#     'Local Incident Number': '23-39887',
#     'Alarm Date': '8/27/2023 12:00:00 AM',
#     'Containment Date': '8/27/2023 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.015996',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '24437.2109375',
#     'Shape__Length': '825.463446811665'},
#    {'_id': 69,
#     'OBJECTID': '69',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'DEN',
#     'Local Incident Number': '23-40087',
#     'Alarm Date': '8/28/2023 12:00:00 AM',
#     'Containment Date': '8/28/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '33.32077',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{C59CE17C-F069-4646-8922-1ECA0149D8C1}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '205300.015625',
#     'Shape__Length': '2251.13933798717'},
#    {'_id': 70,
#     'OBJECTID': '70',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ROLLING',
#     'Local Incident Number': '23-41929',
#     'Alarm Date': '9/9/2023 12:00:00 AM',
#     'Containment Date': '9/9/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7.908133',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E7CF5300-9B71-4F92-A473-EAFC9CC96242}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '48110.3515625',
#     'Shape__Length': '1631.9377204392'},
#    {'_id': 71,
#     'OBJECTID': '71',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TULE',
#     'Local Incident Number': '23-42016',
#     'Alarm Date': '9/9/2023 12:00:00 AM',
#     'Containment Date': '9/10/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7.309518',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A379318A-CF63-458B-BAC2-3825426D025E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '44897.9921875',
#     'Shape__Length': '924.004655341922'},
#    {'_id': 72,
#     'OBJECTID': '72',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'CALIENTE ',
#     'Local Incident Number': '23-43040',
#     'Alarm Date': '9/16/2023 12:00:00 AM',
#     'Containment Date': '9/17/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '55.02539',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{6632FF31-80D4-4C28-9A79-7B7DD5C662A5}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '334837.2265625',
#     'Shape__Length': '3260.97691659367'},
#    {'_id': 73,
#     'OBJECTID': '73',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'FLAT',
#     'Local Incident Number': '23-43755',
#     'Alarm Date': '9/21/2023 12:00:00 AM',
#     'Containment Date': '9/21/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.37647',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8C0DEC8E-6ABE-43F3-9CB4-709F9BF85ADA}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'Shape__Area': '63111.26171875',
#     'Shape__Length': '1553.04377703671'},
#    {'_id': 74,
#     'OBJECTID': '74',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'TOWER ',
#     'Local Incident Number': '23-43839',
#     'Alarm Date': '9/22/2023 12:00:00 AM',
#     'Containment Date': '9/22/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.175606',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{880D76D2-C731-4776-A10D-64D13D3C7E40}',
# ...
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': '3-9',
#     'Local Incident Number': '00000972',
#     'Alarm Date': '8/16/2023 12:00:00 AM',
#     'Containment Date': '11/2/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2836.39',
#     'Comments': None,
#     'Complex Name': 'SOUTH FORK COMPLEX',
#     'IRWIN ID': '{139F46D2-FD28-441A-A53F-E30A5F11454A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{A2EEFB08-1AA8-413D-9D8D-DF4650284399}',
#     'Shape__Area': '19947931.8515625',
#     'Shape__Length': '68191.929473039'},
#    {'_id': 265,
#     'OBJECTID': '265',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'TOWNSEND',
#     'Local Incident Number': '00007031',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '8/23/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '81.23029',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{7C1A08B8-8DAA-41F4-890E-9037B074B3EB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '590216.5859375',
#     'Shape__Length': '4621.79502237563'},
#    {'_id': 266,
#     'OBJECTID': '266',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'SCOTT',
#     'Local Incident Number': '00006941',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '9/4/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1935.952',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{E9353CA9-2BDC-4B36-8A3B-CD488DF69E12}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '14050384.4179688',
#     'Shape__Length': '23549.836633093'},
#    {'_id': 267,
#     'OBJECTID': '267',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'LAKE',
#     'Local Incident Number': '00006975',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '9/7/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '200.2064',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{67FC0630-A544-4A26-9A35-7F21E6CEC675}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '1448786.51171875',
#     'Shape__Length': '8863.5386708356'},
#    {'_id': 268,
#     'OBJECTID': '268',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'DEN',
#     'Local Incident Number': '00007072',
#     'Alarm Date': '8/18/2023 12:00:00 AM',
#     'Containment Date': '8/24/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '294.8512',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{85CD824B-2A6F-4693-ADF7-3A9B01878310}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '2152075.21484375',
#     'Shape__Length': '6968.73287823437'},
#    {'_id': 269,
#     'OBJECTID': '269',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'HANCOCK',
#     'Local Incident Number': '00001016',
#     'Alarm Date': '8/21/2023 12:00:00 AM',
#     'Containment Date': '9/25/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1728.136',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{71F3BE9B-494A-444D-A8AE-C092A852ED04}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '12457944.0898438',
#     'Shape__Length': '18526.7159659813'},
#    {'_id': 270,
#     'OBJECTID': '270',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'PEARCH',
#     'Local Incident Number': '00000983',
#     'Alarm Date': '8/17/2023 12:00:00 AM',
#     'Containment Date': '10/25/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '12152.45',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{F40CFFB2-4238-4FED-A04A-5224984C82E5}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '87295981.7109375',
#     'Shape__Length': '191343.961962366'},
#    {'_id': 271,
#     'OBJECTID': '271',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'LET ER-BUCK',
#     'Local Incident Number': '00000984',
#     'Alarm Date': '8/17/2023 12:00:00 AM',
#     'Containment Date': '9/28/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '95.91678',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{B20E1A0B-FDF4-4C7D-B901-DA502D0E146B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '692201.19140625',
#     'Shape__Length': '7400.7851056973'},
#    {'_id': 272,
#     'OBJECTID': '272',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'IRON',
#     'Local Incident Number': '00001003',
#     'Alarm Date': '8/19/2023 12:00:00 AM',
#     'Containment Date': '9/2/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '20.01698',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{5AAC04E8-A47D-4326-8415-843E204B6E24}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '144629.19921875',
#     'Shape__Length': '1822.03935238628'},
#    {'_id': 273,
#     'OBJECTID': '273',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'PRESCOTT',
#     'Local Incident Number': '00000989',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '11/14/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '599.3448',
#     'Comments': None,
#     'Complex Name': 'SMITH RIVER COMPLEX',
#     'IRWIN ID': '{816563E9-AE8A-41CE-9A6E-21D38AC43D32}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{3BB45524-295D-4F64-8BCB-C0B6DCBC0376}',
#     'Shape__Area': '4357972.8203125',
#     'Shape__Length': '9443.72086280639'},
#    {'_id': 274,
#     'OBJECTID': '274',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'ELLIOT',
#     'Local Incident Number': '00006944',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '10/23/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '13875.25',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{A96DE9BC-0095-43DC-B3E4-81489E63841F}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '100555093.625',
#     'Shape__Length': '92115.6786302958'},
#    {'_id': 275,
#     'OBJECTID': '275',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'TITUS',
#     'Local Incident Number': '00006950',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '8/31/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '71.79534',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{CEBAD372-D78A-4139-BA47-67F696B5DBD2}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '519821.1875',
#     'Shape__Length': '10073.967258063'},
#    {'_id': 276,
#     'OBJECTID': '276',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'UFISH',
#     'Local Incident Number': '00007029',
#     'Alarm Date': '8/16/2023 12:00:00 AM',
#     'Containment Date': '9/28/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7850.58',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{7B4B2AE1-444D-4E86-B4F8-170D81D16D10}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '57036758.5390625',
#     'Shape__Length': '56259.2960477678'},
#    {'_id': 277,
#     'OBJECTID': '277',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'MARLOW',
#     'Local Incident Number': '00000962',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '10/3/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1997.206',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{C6D9B9CB-9C77-4C8E-BA70-1E19114A7108}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '14446716.515625',
#     'Shape__Length': '40356.3638376565'},
#    {'_id': 278,
#     'OBJECTID': '278',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'HURDY GURDY',
#     'Local Incident Number': '00000998',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '11/14/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2677.779',
#     'Comments': None,
#     'Complex Name': 'SMITH RIVER COMPLEX',
#     'IRWIN ID': '{224804E2-996A-4EBC-A200-ABD6A13BFF81}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{3BB45524-295D-4F64-8BCB-C0B6DCBC0376}',
#     'Shape__Area': '19514022.40625',
#     'Shape__Length': '36615.3211235813'},
#    {'_id': 279,
#     'OBJECTID': '279',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'CORRAL',
#     'Local Incident Number': '00000946',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '11/14/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1090.281',
#     'Comments': None,
#     'Complex Name': 'SMITH RIVER COMPLEX',
#     'IRWIN ID': '{0F0D0088-B58E-4ABE-BB1D-24FA874DD8FB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{3BB45524-295D-4F64-8BCB-C0B6DCBC0376}',
#     'Shape__Area': '7980142.2265625',
#     'Shape__Length': '16299.1948251358'},
#    {'_id': 280,
#     'OBJECTID': '280',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'DIAMOND',
#     'Local Incident Number': '00000945',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '11/14/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '550.0559',
#     'Comments': None,
#     'Complex Name': 'SMITH RIVER COMPLEX',
#     'IRWIN ID': '{92EBA8D8-A7B1-4BA0-B3B9-505B46B912DF}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{3BB45524-295D-4F64-8BCB-C0B6DCBC0376}',
#     'Shape__Area': '4026102.2265625',
#     'Shape__Length': '16071.3653112586'},
#    {'_id': 281,
#     'OBJECTID': '281',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'ISLAND',
#     'Local Incident Number': '00000991',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '11/14/2023 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '378.4197',
#     'Comments': None,
#     'Complex Name': 'SMITH RIVER COMPLEX',
#     'IRWIN ID': '{7CEB1406-3733-4E4C-A38A-220FF2F8D662}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{3BB45524-295D-4F64-8BCB-C0B6DCBC0376}',
#     'Shape__Area': '2754376.875',
#     'Shape__Length': '14197.4692313369'},
#    {'_id': 282,
#     'OBJECTID': '282',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'LONE PINE',
#     'Local Incident Number': '00000931',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '9/15/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1684.73',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{D91D2FCB-C4C4-4015-A7AC-15B5B7071716}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '11987004.5546875',
#     'Shape__Length': '19642.4491016105'},
#    {'_id': 283,
#     'OBJECTID': '283',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'SRF',
#     'Fire Name': 'MOSQUITO',
#     'Local Incident Number': '00000954',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '10/25/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '34188.45',
#     'Comments': None,
#     'Complex Name': '2023 SRF LIGHTNING COMPLEX',
#     'IRWIN ID': '{C6CFF715-78DB-4D64-A750-9DB12A048A36}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{16890FB5-5004-4114-B056-1760AD7EB6C1}',
#     'Shape__Area': '246667727.851563',
#     'Shape__Length': '615710.558280471'},
#    {'_id': 284,
#     'OBJECTID': '284',
#     'Year': '2023',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'KNF',
#     'Fire Name': 'HEAD',
#     'Local Incident Number': '00006988',
#     'Alarm Date': '8/15/2023 12:00:00 AM',
#     'Containment Date': '9/7/2023 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '6953.805',
#     'Comments': None,
#     'Complex Name': 'HAPPY CAMP COMPLEX',
#     'IRWIN ID': '{22C55899-C613-43FD-9ED3-5830DECD9073}',
#     'Fire Number (historical use)': None,
#     'Complex ID': '{5CA009DC-D74B-419E-A2E9-0F6231B6191C}',
#     'Shape__Area': '50631460.9257813',
#     'Shape__Length': '90233.5098522921'}],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'OBJECTID', 'type': 'text'},
#    {'id': 'Year', 'type': 'text'},
#    {'id': 'State', 'type': 'text'},
#    {'id': 'Agency', 'type': 'text'},
#    {'id': 'Unit ID', 'type': 'text'},
#    {'id': 'Fire Name', 'type': 'text'},
#    {'id': 'Local Incident Number', 'type': 'text'},
#    {'id': 'Alarm Date', 'type': 'text'},
#    {'id': 'Containment Date', 'type': 'text'},
#    {'id': 'Cause', 'type': 'text'},
#    {'id': 'Collection Method', 'type': 'text'},
#    {'id': 'Management Objective', 'type': 'text'},
#    {'id': 'GIS Calculated Acres', 'type': 'text'},
#    {'id': 'Comments', 'type': 'text'},
#    {'id': 'Complex Name', 'type': 'text'},
#    {'id': 'IRWIN ID', 'type': 'text'},
#    {'id': 'Fire Number (historical use)', 'type': 'text'},
#    {'id': 'Complex ID', 'type': 'text'},
#    {'id': 'Shape__Area', 'type': 'text'},
#    {'id': 'Shape__Length', 'type': 'text'}],
#   '_links': {'start': '/api/3/action/datastore_search?limit=284&resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991',
#    'next': '/api/3/action/datastore_search?limit=284&resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991&offset=284'},
#   'total': 16991,
#   'total_was_estimated': False}}
