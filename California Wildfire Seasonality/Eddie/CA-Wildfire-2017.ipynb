# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
from datetime import datetime
import os
import csv

# %%
# Save config information.
url = "https://data.ca.gov/api/3/action/datastore_search?resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991&"

# Build partial query URL
limit = 1000
year = 2017
query_url = f"{url}&limit={limit}&q={year}"
response = requests.get(query_url).json()
response
# Out:
# {'help': 'https://data.ca.gov/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 1000,
#   'q': '2017',
#   'records_format': 'objects',
#   'resource_id': 'd73ee828-c2c6-485c-91dc-c26bd9ce3991',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 2257,
#     'OBJECTID': '2257',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'POINT',
#     'Local Incident Number': '00012170',
#     'Alarm Date': '10/9/2017 12:00:00 AM',
#     'Containment Date': '10/9/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '130.2357',
#     'Comments': 'October 2017 Siege',
#     'Complex Name': None,
#     'IRWIN ID': '{DAF778E8-6421-473B-A17E-CCFC0172B16E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '859542.81640625',
#     'Shape__Length': '7792.198462983',
#     'rank': 0.0706241},
#    {'_id': 2756,
#     'OBJECTID': '2756',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BEU',
#     'Fire Name': 'PINE',
#     'Local Incident Number': '00004818',
#     'Alarm Date': '9/11/2017 12:00:00 AM',
#     'Containment Date': '9/11/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '59.3685',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '369426.671875',
#     'Shape__Length': '3024.42065330089',
#     'rank': 0.057308756},
#    {'_id': 2017,
#     'OBJECTID': '2017',
#     'Year': '2018',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'ORC',
#     'Fire Name': 'CREEK',
#     'Local Incident Number': '18011407',
#     'Alarm Date': '1/28/2018 12:00:00 AM',
#     'Containment Date': '1/28/2018 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.4142567',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2417.05859375',
#     'Shape__Length': '220.265598016722',
#     'rank': 0.057308756},
#    {'_id': 2253,
#     'OBJECTID': '2253',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'TABLE',
#     'Local Incident Number': '00011308',
#     'Alarm Date': '9/19/2017 12:00:00 AM',
#     'Containment Date': '9/19/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '38.80263',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '252657.4609375',
#     'Shape__Length': '3390.41288924791',
#     'rank': 0.057308756},
#    {'_id': 2359,
#     'OBJECTID': '2359',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'ORC',
#     'Fire Name': ' ',
#     'Local Incident Number': '17095310',
#     'Alarm Date': '8/31/2017 12:00:00 AM',
#     'Containment Date': '8/31/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.02271913',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '132.9609375',
#     'Shape__Length': '53.0695330447129',
#     'rank': 0.057308756},
#    {'_id': 2219,
#     'OBJECTID': '2219',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'BROOK',
#     'Local Incident Number': '00042450',
#     'Alarm Date': '5/23/2017 12:00:00 AM',
#     'Containment Date': '5/24/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.04382',
#     'Comments': 'per walked track',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '59473.66015625',
#     'Shape__Length': '1246.05578095928',
#     'rank': 0.057308756},
#    {'_id': 2220,
#     'OBJECTID': '2220',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'PACIFIC',
#     'Local Incident Number': '00075307',
#     'Alarm Date': '9/9/2017 12:00:00 AM',
#     'Containment Date': '9/9/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.190109',
#     'Comments': 'Final Walked track.  Small spot to the north east',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '7081.38671875',
#     'Shape__Length': '561.418201925858',
#     'rank': 0.057308756},
#    {'_id': 2221,
#     'OBJECTID': '2221',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'GRADE',
#     'Local Incident Number': '00054660',
#     'Alarm Date': '7/4/2017 12:00:00 AM',
#     'Containment Date': '7/5/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '47.19403',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '279911.85546875',
#     'Shape__Length': '2587.25969682798',
#     'rank': 0.057308756},
#    {'_id': 2222,
#     'OBJECTID': '2222',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'PACIFICA',
#     'Local Incident Number': '00051791',
#     'Alarm Date': '6/24/2017 12:00:00 AM',
#     'Containment Date': '6/24/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.158548',
#     'Comments': 'GPS track',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '6859.6796875',
#     'Shape__Length': '501.17810228652',
#     'rank': 0.057308756},
#    {'_id': 2223,
#     'OBJECTID': '2223',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'MONTVIEW',
#     'Local Incident Number': '00040196',
#     'Alarm Date': '5/15/2017 12:00:00 AM',
#     'Containment Date': '5/15/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.893327',
#     'Comments': 'Rough per description.  waiting for walked GPS tr*',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '17133.0078125',
#     'Shape__Length': '484.388886664416',
#     'rank': 0.057308756},
#    {'_id': 2224,
#     'OBJECTID': '2224',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'PALMA',
#     'Local Incident Number': '00089782',
#     'Alarm Date': '10/21/2017 12:00:00 AM',
#     'Containment Date': '10/21/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.187291',
#     'Comments': 'gps track',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '7047.37109375',
#     'Shape__Length': '361.794915832203',
#     'rank': 0.057308756},
#    {'_id': 2225,
#     'OBJECTID': '2225',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'CANYON',
#     'Local Incident Number': '00059614',
#     'Alarm Date': '7/19/2017 12:00:00 AM',
#     'Containment Date': None,
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '30.4916',
#     'Comments': 'VNC into FRA on intitial attack, Fed inc # 1924',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '181885.74609375',
#     'Shape__Length': '3383.21904427323',
#     'rank': 0.057308756},
#    {'_id': 2226,
#     'OBJECTID': '2226',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'VISTA',
#     'Local Incident Number': '00091038',
#     'Alarm Date': '10/24/2017 12:00:00 AM',
#     'Containment Date': '10/26/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '86.39403',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{1108077A-C453-48E7-B377-61FD343A0A77}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '514307.4140625',
#     'Shape__Length': '4514.56944340242',
#     'rank': 0.057308756},
#    {'_id': 2227,
#     'OBJECTID': '2227',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'BALDWIN',
#     'Local Incident Number': '00049252',
#     'Alarm Date': '6/16/2017 12:00:00 AM',
#     'Containment Date': '6/16/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.296595',
#     'Comments': 'Per walked GPS track',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '13691.89453125',
#     'Shape__Length': '493.231028484406',
#     'rank': 0.057308756},
#    {'_id': 2228,
#     'OBJECTID': '2228',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'ROLLING',
#     'Local Incident Number': '00063742',
#     'Alarm Date': '8/3/2017 12:00:00 AM',
#     'Containment Date': '8/3/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3.923584',
#     'Comments': 'Final.  Walked GPS',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '23256.375',
#     'Shape__Length': '778.71846973505',
#     'rank': 0.057308756},
#    {'_id': 2229,
#     'OBJECTID': '2229',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'MCWANE',
#     'Local Incident Number': '00041882',
#     'Alarm Date': '5/21/2017 12:00:00 AM',
#     'Containment Date': '5/21/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.751291',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '10372.32421875',
#     'Shape__Length': '421.532158348047',
#     'rank': 0.057308756},
#    {'_id': 2230,
#     'OBJECTID': '2230',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'SCHOOL\nSCHOOL',
#     'Local Incident Number': '00100005',
#     'Alarm Date': '11/23/2017 12:00:00 AM',
#     'Containment Date': '11/23/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.666061',
#     'Comments': 'Animal caused electrical arcing',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '27760.71875',
#     'Shape__Length': '1113.85738939902',
#     'rank': 0.057308756},
#    {'_id': 2231,
#     'OBJECTID': '2231',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'FORK',
#     'Local Incident Number': '00035362',
#     'Alarm Date': '4/28/2017 12:00:00 AM',
#     'Containment Date': '4/28/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.534435',
#     'Comments': 'Walked track',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '9130.51171875',
#     'Shape__Length': '846.129704469438',
#     'rank': 0.057308756},
#    {'_id': 2232,
#     'OBJECTID': '2232',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'LIBBEY',
#     'Local Incident Number': '00032047',
#     'Alarm Date': '4/16/2017 12:00:00 AM',
#     'Containment Date': '4/16/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.227261',
#     'Comments': 'Unintentional',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '13288.72265625',
#     'Shape__Length': '494.937596813145',
#     'rank': 0.057308756},
#    {'_id': 2233,
#     'OBJECTID': '2233',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'SCALES',
#     'Local Incident Number': '00113112',
#     'Alarm Date': '12/21/2017 12:00:00 AM',
#     'Containment Date': '12/21/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.25824',
#     'Comments': 'Walked perimter',
#     'Complex Name': None,
#     'IRWIN ID': '{E1B1545B-AC69-475B-A9B9-7CDBD9A2D98E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '7462.04296875',
#     'Shape__Length': '697.889451565569',
#     'rank': 0.057308756},
#    {'_id': 2234,
#     'OBJECTID': '2234',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'CANYON',
#     'Local Incident Number': '00110784',
#     'Alarm Date': '7/19/2017 12:00:00 AM',
#     'Containment Date': None,
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.550757',
#     'Comments': 'VNC into FRA on intitial attack',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '32979.1328125',
#     'Shape__Length': '972.485221577203',
#     'rank': 0.057308756},
#    {'_id': 2235,
#     'OBJECTID': '2235',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'RUNNER',
#     'Local Incident Number': '00104509',
#     'Alarm Date': '12/5/2017 12:00:00 AM',
#     'Containment Date': '12/5/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.425504',
#     'Comments': 'Unintentional',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '14386.8828125',
#     'Shape__Length': '535.699626786195',
#     'rank': 0.057308756},
#    {'_id': 2236,
#     'OBJECTID': '2236',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TUU',
#     'Fire Name': 'DINELY',
#     'Local Incident Number': '00000286',
#     'Alarm Date': '6/7/2017 12:00:00 AM',
#     'Containment Date': '6/11/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '340.5638',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{333C6D27-EC54-4DFA-8033-1FC6845E617C}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2135860.55078125',
#     'Shape__Length': '5770.50529170968',
#     'rank': 0.057308756},
#    {'_id': 2237,
#     'OBJECTID': '2237',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TUU',
#     'Fire Name': 'ROADRUNNER',
#     'Local Incident Number': '00000441',
#     'Alarm Date': '7/30/2017 12:00:00 AM',
#     'Containment Date': '8/1/2017 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2284.596',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{946BB763-3BC6-4BD1-AA8B-E87AFCD08E5E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '14160895.7929688',
#     'Shape__Length': '25151.3723031783',
#     'rank': 0.057308756},
#    {'_id': 2238,
#     'OBJECTID': '2238',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TUU',
#     'Fire Name': 'ELEPHANT 2',
#     'Local Incident Number': '00000420',
#     'Alarm Date': '7/20/2017 12:00:00 AM',
#     'Containment Date': '7/22/2017 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '415.2116',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{614C80B0-A8DF-4942-A6DD-C7EC7595F792}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2586629.79296875',
#     'Shape__Length': '9434.27481732818',
#     'rank': 0.057308756},
#    {'_id': 2239,
#     'OBJECTID': '2239',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TGU',
#     'Fire Name': 'TEHAMA',
#     'Local Incident Number': '00010345',
#     'Alarm Date': '10/30/2017 12:00:00 AM',
#     'Containment Date': '10/31/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '194.0017',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{108C0023-72F4-4AF1-8135-F870F5E8A28B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1345001.4765625',
#     'Shape__Length': '6019.3469441985',
#     'rank': 0.057308756},
#    {'_id': 2240,
#     'OBJECTID': '2240',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TGU',
#     'Fire Name': 'BOLLA',
#     'Local Incident Number': '00005782',
#     'Alarm Date': '6/18/2017 12:00:00 AM',
#     'Containment Date': '6/21/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '60.31167',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '420580.109375',
#     'Shape__Length': '3421.6962833346',
#     'rank': 0.057308756},
#    {'_id': 2241,
#     'OBJECTID': '2241',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'CRABTREE',
#     'Local Incident Number': '00007212',
#     'Alarm Date': '6/21/2017 12:00:00 AM',
#     'Containment Date': '6/21/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '14.1566',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '91558.2578125',
#     'Shape__Length': '1318.41358433401',
#     'rank': 0.057308756},
#    {'_id': 2242,
#     'OBJECTID': '2242',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'FALLS',
#     'Local Incident Number': '00009206',
#     'Alarm Date': '8/1/2017 12:00:00 AM',
#     'Containment Date': '8/1/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '20.31024',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '131390.5703125',
#     'Shape__Length': '1777.73370666502',
#     'rank': 0.057308756},
#    {'_id': 2243,
#     'OBJECTID': '2243',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'GOLD',
#     'Local Incident Number': '00007925',
#     'Alarm Date': '7/5/2017 12:00:00 AM',
#     'Containment Date': '7/5/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '33.16441',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '217008.078125',
#     'Shape__Length': '2594.37635215854',
#     'rank': 0.057308756},
#    {'_id': 2244,
#     'OBJECTID': '2244',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'HARNEY',
#     'Local Incident Number': '00011513',
#     'Alarm Date': '9/24/2017 12:00:00 AM',
#     'Containment Date': '9/24/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '37.42143',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '244961.7734375',
#     'Shape__Length': '2951.13698994478',
#     'rank': 0.057308756},
#    {'_id': 2245,
#     'OBJECTID': '2245',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'JACKSONVILLE',
#     'Local Incident Number': '00009024',
#     'Alarm Date': '7/29/2017 12:00:00 AM',
#     'Containment Date': '7/30/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '684.3565',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{7034C0BF-F133-4FE0-8BEB-898512CA1716}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '4455425.36328125',
#     'Shape__Length': '14049.8919800805',
#     'rank': 0.057308756},
#    {'_id': 2246,
#     'OBJECTID': '2246',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'LAKE',
#     'Local Incident Number': '00008047',
#     'Alarm Date': '7/8/2017 12:00:00 AM',
#     'Containment Date': '7/8/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '62.34454',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '403196.140625',
#     'Shape__Length': '3189.55809463085',
#     'rank': 0.057308756},
#    {'_id': 2247,
#     'OBJECTID': '2247',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'MARIA',
#     'Local Incident Number': '00008497',
#     'Alarm Date': '7/17/2017 12:00:00 AM',
#     'Containment Date': '7/17/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '114.5601',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{069ACB89-1427-4F80-87CE-3049F43EDC21}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '753888.72265625',
#     'Shape__Length': '4994.45207049929',
#     'rank': 0.057308756},
#    {'_id': 2248,
#     'OBJECTID': '2248',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'MILTON',
#     'Local Incident Number': '00012544',
#     'Alarm Date': '10/18/2017 12:00:00 AM',
#     'Containment Date': '10/18/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '17.96167',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '117370.3203125',
#     'Shape__Length': '1672.49455757281',
#     'rank': 0.057308756},
#    {'_id': 2249,
#     'OBJECTID': '2249',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'ORANGE',
#     'Local Incident Number': '00007220',
#     'Alarm Date': '6/21/2017 12:00:00 AM',
#     'Containment Date': '6/21/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '64.52619',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '419304.81640625',
#     'Shape__Length': '4842.11290015605',
#     'rank': 0.057308756},
#    {'_id': 2250,
#     'OBJECTID': '2250',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'PALOMA',
#     'Local Incident Number': '00008560',
#     'Alarm Date': '7/18/2017 12:00:00 AM',
#     'Containment Date': '7/18/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '13.38323',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{766C6020-EF2F-41D9-9606-E6168FA641DF}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '87982',
#     'Shape__Length': '1458.98856719796',
#     'rank': 0.057308756},
#    {'_id': 2251,
#     'OBJECTID': '2251',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'QUAIL',
#     'Local Incident Number': '00008249',
#     'Alarm Date': '7/12/2017 12:00:00 AM',
#     'Containment Date': '7/12/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '59.38209',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{D32E7FBD-0721-43C4-83EE-9C65A88FDE8A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '389527.23046875',
#     'Shape__Length': '3107.30468132169',
#     'rank': 0.057308756},
#    {'_id': 2252,
#     'OBJECTID': '2252',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'RED',
#     'Local Incident Number': '00006716',
#     'Alarm Date': '6/11/2017 12:00:00 AM',
#     'Containment Date': '6/11/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '38.10066',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{77D1989F-9314-4B70-A6CC-5F30D92F104B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '247730.21484375',
#     'Shape__Length': '2837.98176070841',
#     'rank': 0.057308756},
#    {'_id': 2254,
#     'OBJECTID': '2254',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'TWIST',
#     'Local Incident Number': '00009089',
#     'Alarm Date': '7/30/2017 12:00:00 AM',
#     'Containment Date': '7/30/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '124.244',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{F9DA5313-BDCF-428D-8513-C604488A2E8A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '808519.640625',
#     'Shape__Length': '6554.24368661927',
#     'rank': 0.057308756},
#    {'_id': 2255,
#     'OBJECTID': '2255',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'WILLMS',
#     'Local Incident Number': '00008573',
#     'Alarm Date': '7/18/2017 12:00:00 AM',
#     'Containment Date': '7/18/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '18.7433',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '121753.3125',
#     'Shape__Length': '1580.73594986131',
#     'rank': 0.057308756},
#    {'_id': 2256,
#     'OBJECTID': '2256',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TCU',
#     'Fire Name': 'ZAMORA',
#     'Local Incident Number': '00009864',
#     'Alarm Date': '8/15/2017 12:00:00 AM',
#     'Containment Date': '8/15/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '23.79608',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '153833.57421875',
#     'Shape__Length': '1763.77692619645',
#     'rank': 0.057308756},
#    {'_id': 2258,
#     'OBJECTID': '2258',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'ROCKY',
#     'Local Incident Number': '00005555',
#     'Alarm Date': '5/20/2017 12:00:00 AM',
#     'Containment Date': '5/20/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '21.9278',
#     'Comments': 'non commercial use',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '134124.56640625',
#     'Shape__Length': '2569.15329059703',
#     'rank': 0.057308756},
#    {'_id': 2259,
#     'OBJECTID': '2259',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'SHANDON',
#     'Local Incident Number': '00005101',
#     'Alarm Date': '5/7/2017 12:00:00 AM',
#     'Containment Date': '5/7/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '12.07228',
#     'Comments': 'Hot Exhaust',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '74235.10546875',
#     'Shape__Length': '1323.8037565803',
#     'rank': 0.057308756},
#    {'_id': 2260,
#     'OBJECTID': '2260',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'SOLAR',
#     'Local Incident Number': '00006106',
#     'Alarm Date': '6/3/2017 12:00:00 AM',
#     'Containment Date': '6/3/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.10916',
#     'Comments': 'Solar Panel Electrical Failure',
#     'Complex Name': None,
#     'IRWIN ID': '{34CC1950-D4CA-4D2C-A9FA-5AA2B77C7B94}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '67691.234375',
#     'Shape__Length': '1194.51521323871',
#     'rank': 0.057308756},
#    {'_id': 2261,
#     'OBJECTID': '2261',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'LUCY',
#     'Local Incident Number': '00006548',
#     'Alarm Date': '6/14/2017 12:00:00 AM',
#     'Containment Date': '6/14/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '147.667',
#     'Comments': 'Bird into energized power lines',
#     'Complex Name': None,
#     'IRWIN ID': '{E30596A1-8879-4CF3-ADC7-DFA04F5D6554}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '908154.1875',
#     'Shape__Length': '4612.82258883665',
#     'rank': 0.057308756},
#    {'_id': 2262,
#     'OBJECTID': '2262',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'TOWER',
#     'Local Incident Number': '00007678',
#     'Alarm Date': '7/7/2017 12:00:00 AM',
#     'Containment Date': '7/7/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '63.51402',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{0C68933F-809A-4637-BBC5-5B6288C251C0}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '387219.9140625',
#     'Shape__Length': '3058.47416382956',
#     'rank': 0.057308756},
#    {'_id': 2263,
#     'OBJECTID': '2263',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'OLIVE',
#     'Local Incident Number': '00008451',
#     'Alarm Date': '7/24/2017 12:00:00 AM',
#     'Containment Date': '7/24/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '236.8678',
#     'Comments': 'Overheated brake and or AC clutch parts',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1459364.4296875',
#     'Shape__Length': '6779.90840508753',
#     'rank': 0.057308756},
#    {'_id': 2264,
#     'OBJECTID': '2264',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'CYPRESS',
#     'Local Incident Number': '00008470',
#     'Alarm Date': '7/24/2017 12:00:00 AM',
#     'Containment Date': '7/24/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '21.28955',
#     'Comments': 'Powerlines/vegetation contact',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '130610.97265625',
#     'Shape__Length': '1836.49875922341',
#     'rank': 0.057308756},
#    {'_id': 2265,
#     'OBJECTID': '2265',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'CHALK',
#     'Local Incident Number': '00007725',
#     'Alarm Date': '7/8/2017 12:00:00 AM',
#     'Containment Date': '7/8/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '18.82862',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '115132.4375',
#     'Shape__Length': '2010.02155401657',
#     'rank': 0.057308756},
#    {'_id': 2266,
#     'OBJECTID': '2266',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'STONE',
#     'Local Incident Number': '00007792',
#     'Alarm Date': '7/9/2017 12:00:00 AM',
#     'Containment Date': '7/11/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '340.4365',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{563401A1-E681-4DAB-AA15-7C27B848C603}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2080074.30859375',
#     'Shape__Length': '9883.25949180918',
#     'rank': 0.057308756},
#    {'_id': 2267,
#     'OBJECTID': '2267',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'WEST',
#     'Local Incident Number': '00008747',
#     'Alarm Date': '7/31/2017 12:00:00 AM',
#     'Containment Date': '7/31/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.34279',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '69218.3984375',
#     'Shape__Length': '1780.41171537611',
#     'rank': 0.057308756},
#    {'_id': 2268,
#     'OBJECTID': '2268',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'ALAMO',
#     'Local Incident Number': '00007624',
#     'Alarm Date': '7/6/2017 12:00:00 AM',
#     'Containment Date': '7/20/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '28834.17',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{08D1626D-4EBA-47C0-ABBE-878DE60CA985}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '174173285.40625',
#     'Shape__Length': '117396.899748312',
#     'rank': 0.057308756},
#    {'_id': 2269,
#     'OBJECTID': '2269',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'HILL',
#     'Local Incident Number': '00007101',
#     'Alarm Date': '6/26/2017 12:00:00 AM',
#     'Containment Date': '6/30/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1645.591',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{6173D340-9000-46A7-AFC1-037AC8D622C7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '10046595.1289063',
#     'Shape__Length': '21464.2463392136',
#     'rank': 0.057308756},
#    {'_id': 2270,
#     'OBJECTID': '2270',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'GAVIOTA',
#     'Local Incident Number': '00006569',
#     'Alarm Date': '6/14/2017 12:00:00 AM',
#     'Containment Date': '6/14/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '20.31965',
#     'Comments': 'Spontaneous combustion to soil/fertilizer',
#     'Complex Name': None,
#     'IRWIN ID': '{4952BCEE-8E72-4B24-9AFB-0964A8D5D4D7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '123720.09765625',
#     'Shape__Length': '1555.5337819451',
#     'rank': 0.057308756},
#    {'_id': 2271,
#     'OBJECTID': '2271',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'ZENON',
#     'Local Incident Number': '00008291',
#     'Alarm Date': '7/20/2017 12:00:00 AM',
#     'Containment Date': '7/20/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '46.57753',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{19437D46-950F-4D2D-8B66-4845043D788F}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '281961.69921875',
#     'Shape__Length': '3251.98128159657',
#     'rank': 0.057308756},
#    {'_id': 2272,
#     'OBJECTID': '2272',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'CAMATTA',
#     'Local Incident Number': '00008802',
#     'Alarm Date': '8/2/2017 12:00:00 AM',
#     'Containment Date': '8/2/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '70.57708',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '431262.36328125',
#     'Shape__Length': '3635.18760432019',
#     'rank': 0.057308756},
#    {'_id': 2273,
#     'OBJECTID': '2273',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'RANCH',
#     'Local Incident Number': '00009236',
#     'Alarm Date': '8/13/2017 12:00:00 AM',
#     'Containment Date': '8/13/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '12.45207',
#     'Comments': 'Sparks from dragging chains',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '76400.359375',
#     'Shape__Length': '1488.61794168679',
#     'rank': 0.057308756},
#    {'_id': 2274,
#     'OBJECTID': '2274',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'MARGARITA',
#     'Local Incident Number': '00010107',
#     'Alarm Date': '9/3/2017 12:00:00 AM',
#     'Containment Date': '9/3/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '69.71004',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{C75D4274-0F4C-4BF7-8CFC-2AD4DCA996CA}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '424525.62109375',
#     'Shape__Length': '3032.82713971317',
#     'rank': 0.057308756},
#    {'_id': 2275,
#     'OBJECTID': '2275',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'HUASNA',
#     'Local Incident Number': '00010788',
#     'Alarm Date': '9/20/2017 12:00:00 AM',
#     'Containment Date': '9/20/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '244.789',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{9C8AADD4-0962-4C68-8FDE-5C23DD16FB33}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1485343.83203125',
#     'Shape__Length': '7140.34209528144',
#     'rank': 0.057308756},
#    {'_id': 2276,
#     'OBJECTID': '2276',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'COVE',
#     'Local Incident Number': '00010920',
#     'Alarm Date': '9/23/2017 12:00:00 AM',
#     'Containment Date': '9/23/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '24.77047',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{07F8DF28-AC53-4185-84B0-3755B3E65F5B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '152567.70703125',
#     'Shape__Length': '1944.58943951147',
#     'rank': 0.057308756},
#    {'_id': 2277,
#     'OBJECTID': '2277',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'POLY',
#     'Local Incident Number': '00011022',
#     'Alarm Date': '9/26/2017 12:00:00 AM',
#     'Containment Date': '9/29/2017 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '105.6661',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8FD4A991-CD99-44E4-95C0-C87D7A2F8A3A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '643426.921875',
#     'Shape__Length': '5209.70658352061',
#     'rank': 0.057308756},
#    {'_id': 2278,
#     'OBJECTID': '2278',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'LINNE',
#     'Local Incident Number': '00022025',
#     'Alarm Date': '9/26/2017 12:00:00 AM',
#     'Containment Date': '9/26/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '74.80467',
#     'Comments': 'Roadside',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '458973.65234375',
#     'Shape__Length': '3366.04190472758',
#     'rank': 0.057308756},
#    {'_id': 2279,
#     'OBJECTID': '2279',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'SODA',
#     'Local Incident Number': '00011961',
#     'Alarm Date': '10/20/2017 12:00:00 AM',
#     'Containment Date': '10/20/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '30.651',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{B00520B3-1FDC-475A-84C3-010DAC4543B8}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '187213.04296875',
#     'Shape__Length': '2165.83419507756',
#     'rank': 0.057308756},
#    {'_id': 2280,
#     'OBJECTID': '2280',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'LYNCH',
#     'Local Incident Number': '00011676',
#     'Alarm Date': '10/19/2017 12:00:00 AM',
#     'Containment Date': '10/19/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '71.18116',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{91AE4A65-74F5-4A25-A559-378A65C1B917}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '438665.3984375',
#     'Shape__Length': '5210.50157707057',
#     'rank': 0.057308756},
#    {'_id': 2281,
#     'OBJECTID': '2281',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'CAMP',
#     'Local Incident Number': '00005454',
#     'Alarm Date': '5/15/2017 12:00:00 AM',
#     'Containment Date': '5/15/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '253.9364',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1548040.46875',
#     'Shape__Length': '6770.59925899409',
#     'rank': 0.057308756},
#    {'_id': 2282,
#     'OBJECTID': '2282',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'VILLA',
#     'Local Incident Number': '00008621',
#     'Alarm Date': '7/28/2017 12:00:00 AM',
#     'Containment Date': '7/28/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.20885',
#     'Comments': 'Energized arching power lines',
#     'Complex Name': None,
#     'IRWIN ID': '{7A36D8DA-81F7-4234-A0AF-C9C7DE7185AB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '62426.15625',
#     'Shape__Length': '1021.55884512601',
#     'rank': 0.057308756},
#    {'_id': 2283,
#     'OBJECTID': '2283',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'OLIVE',
#     'Local Incident Number': '00004896',
#     'Alarm Date': '5/2/2017 12:00:00 AM',
#     'Containment Date': '5/2/2017 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '117.0671',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{960096A9-8A33-45D1-9B79-F51F4929AB3D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '721275.734375',
#     'Shape__Length': '4711.92522316224',
#     'rank': 0.057308756},
#    {'_id': 2284,
#     'OBJECTID': '2284',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SKU',
#     'Fire Name': 'CRAM',
#     'Local Incident Number': '00001334',
#     'Alarm Date': '2/14/2017 12:00:00 AM',
#     'Containment Date': '2/14/2017 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '16.0521',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '116125.8359375',
#     'Shape__Length': '1638.99711790848',
#     'rank': 0.057308756},
#    {'_id': 2285,
#     'OBJECTID': '2285',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SKU',
# ...
#     'Local Incident Number': '00000086',
#     'Alarm Date': '8/2/2017 12:00:00 AM',
#     'Containment Date': '11/3/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '56.16541',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{2D44AE37-3ECA-4147-9F1F-4C07CBFBA806}',
#     'Fire Number (historical use)': '86',
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '363849.640625',
#     'Shape__Length': '4415.59846779984',
#     'rank': 0.057308756},
#    {'_id': 2808,
#     'OBJECTID': '2808',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'NPS',
#     'Unit ID': 'YNP',
#     'Fire Name': 'CRANE',
#     'Local Incident Number': '00000142',
#     'Alarm Date': '9/20/2017 12:00:00 AM',
#     'Containment Date': '9/20/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.07941185',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{BAE77E0A-1B6F-4AD6-A552-DB24E6F1EE4A}',
#     'Fire Number (historical use)': '142',
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '514.8515625',
#     'Shape__Length': '81.3708555282933',
#     'rank': 0.057308756},
#    {'_id': 2809,
#     'OBJECTID': '2809',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'LDF',
#     'Fire Name': 'LA TUNA',
#     'Local Incident Number': '00000965',
#     'Alarm Date': '9/1/2017 12:00:00 AM',
#     'Containment Date': '9/8/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7051.351',
#     'Comments': '5 residential structures, 5 outbuildings lost',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '41848445.265625',
#     'Shape__Length': '39362.4635113843',
#     'rank': 0.057308756},
#    {'_id': 2810,
#     'OBJECTID': '2810',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'MDF',
#     'Fire Name': 'PARKER2 ',
#     'Local Incident Number': '00000862',
#     'Alarm Date': '8/3/2017 12:00:00 AM',
#     'Containment Date': '8/15/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7693.319',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{9DEC180B-7F52-4A56-8559-307844FED367}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '55487039.4335938',
#     'Shape__Length': '154167.754522116',
#     'rank': 0.057308756},
#    {'_id': 2811,
#     'OBJECTID': '2811',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'NPS',
#     'Unit ID': 'YNP',
#     'Fire Name': 'SOUTH FORK',
#     'Local Incident Number': '00000108',
#     'Alarm Date': '8/13/2017 12:00:00 AM',
#     'Containment Date': '11/3/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7560.077',
#     'Comments': 'no new growth past 10/11',
#     'Complex Name': None,
#     'IRWIN ID': '{16DBB6FA-1D4C-4FED-9DF6-D08875DF84DD}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '48763696.6640625',
#     'Shape__Length': '109839.559860642',
#     'rank': 0.057308756},
#    {'_id': 2812,
#     'OBJECTID': '2812',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'REDWOOD VALLEY',
#     'Local Incident Number': '00012172',
#     'Alarm Date': '10/8/2017 12:00:00 AM',
#     'Containment Date': '10/25/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '36522.95',
#     'Comments': None,
#     'Complex Name': 'MENDOCINO LAKE COMPLEX',
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '247373450.597656',
#     'Shape__Length': '138169.276738241',
#     'rank': 0.057308756},
#    {'_id': 2813,
#     'OBJECTID': '2813',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'RRS',
#     'Fire Name': 'ABNEY',
#     'Local Incident Number': '00000568',
#     'Alarm Date': '8/10/2017 12:00:00 AM',
#     'Containment Date': '1/9/2018 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '32893.26',
#     'Comments': None,
#     'Complex Name': 'MILLER COMPLEX',
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '240885915.570313',
#     'Shape__Length': '174124.472395045',
#     'rank': 0.057308756},
#    {'_id': 2814,
#     'OBJECTID': '2814',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'RRS',
#     'Fire Name': 'KNOX',
#     'Local Incident Number': '00000612',
#     'Alarm Date': '8/11/2017 12:00:00 AM',
#     'Containment Date': '11/28/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '492.5997',
#     'Comments': 'CONTDATE based on fire out date',
#     'Complex Name': 'MILLER COMPLEX',
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': 'K9PL',
#     'DECADES': '2010',
#     'Shape__Area': '3608915.0234375',
#     'Shape__Length': '14253.2429479054',
#     'rank': 0.057308756},
#    {'_id': 2815,
#     'OBJECTID': '2815',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'INF',
#     'Fire Name': 'GOODALE',
#     'Local Incident Number': '00001157',
#     'Alarm Date': '7/24/2017 12:00:00 AM',
#     'Containment Date': '8/28/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.1962595',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{2664A79B-4D1E-4CDC-B5C0-898C3DBC1DE2}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1246.75',
#     'Shape__Length': '139.542486560575',
#     'rank': 0.057308756},
#    {'_id': 2816,
#     'OBJECTID': '2816',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'ENF',
#     'Fire Name': 'FORNI',
#     'Local Incident Number': '00023406',
#     'Alarm Date': '8/11/2017 12:00:00 AM',
#     'Containment Date': '8/14/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '12.26719',
#     'Comments': 'maybe campfire start',
#     'Complex Name': None,
#     'IRWIN ID': '{390F1DEB-DEF4-4B5A-AA1D-58CBCED84151}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '81909.8828125',
#     'Shape__Length': '1187.06066228701',
#     'rank': 0.057308756},
#    {'_id': 2817,
#     'OBJECTID': '2817',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'DOD',
#     'Unit ID': 'MCP',
#     'Fire Name': 'CRISTIANITOS',
#     'Local Incident Number': '01702047',
#     'Alarm Date': '6/28/2017 12:00:00 AM',
#     'Containment Date': '6/30/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '5',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '702.3066',
#     'Comments': 'started by RC bicycle',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '4091712.1640625',
#     'Shape__Length': '17412.8486395927',
#     'rank': 0.057308756},
#    {'_id': 2818,
#     'OBJECTID': '2818',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'LAC',
#     'Fire Name': 'TOPANGA',
#     'Local Incident Number': '00191835',
#     'Alarm Date': '6/29/2017 12:00:00 AM',
#     'Containment Date': '7/2/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '20.00055',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{481687B7-6B0A-480B-A7A3-5E7F323AC224}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '118210.6953125',
#     'Shape__Length': '2543.84169062352',
#     'rank': 0.057308756},
#    {'_id': 2819,
#     'OBJECTID': '2819',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'LDF',
#     'Fire Name': 'SKIRBALL',
#     'Local Incident Number': '00030179',
#     'Alarm Date': '12/6/2017 12:00:00 AM',
#     'Containment Date': '12/15/2017 12:00:00 AM',
#     'Cause': '4',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '419.9208',
#     'Comments': 'FIMT most info from LAFD website, homelss cook fire',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2484304.62890625',
#     'Shape__Length': '9961.23040661275',
#     'rank': 0.057308756},
#    {'_id': 2820,
#     'OBJECTID': '2820',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': '37',
#     'Local Incident Number': '00002957',
#     'Alarm Date': '10/9/2017 12:00:00 AM',
#     'Containment Date': '10/16/2017 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1613.219',
#     'Comments': 'LFB8.  DIGITIZED FROM DIGITALGLOBE (MAXAR) IMAGERY.',
#     'Complex Name': None,
#     'IRWIN ID': '{F570C977-2D96-4BB0-A146-52D1A32FA87D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '10574590.0585938',
#     'Shape__Length': '46336.0509447769',
#     'rank': 0.057308756},
#    {'_id': 2821,
#     'OBJECTID': '2821',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'PLR',
#     'Fire Name': 'TURKEY TRACT',
#     'Local Incident Number': '00001706',
#     'Alarm Date': '8/16/2017 12:00:00 AM',
#     'Containment Date': '8/16/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '150.2368',
#     'Comments': 'K916',
#     'Complex Name': None,
#     'IRWIN ID': '{FF573940-6ABC-4C67-B826-C9C7D9AC28D1}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '928729.19921875',
#     'Shape__Length': '4849.21280868562',
#     'rank': 0.057308756},
#    {'_id': 2822,
#     'OBJECTID': '2822',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'BRR',
#     'Fire Name': 'STUBBLE',
#     'Local Incident Number': '00002027',
#     'Alarm Date': '7/27/2017 12:00:00 AM',
#     'Containment Date': '7/27/2017 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.526605',
#     'Comments': 'LAH8',
#     'Complex Name': None,
#     'IRWIN ID': '{96228AF8-4967-4AE1-B2CE-CDAC6C8B06EF}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '9217.671875',
#     'Shape__Length': '1259.80853309261',
#     'rank': 0.057308756},
#    {'_id': 2823,
#     'OBJECTID': '2823',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'HUDSON',
#     'Local Incident Number': '00027936',
#     'Alarm Date': '7/18/2017 12:00:00 AM',
#     'Containment Date': '7/18/2017 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1175.391',
#     'Comments': 'K506.',
#     'Complex Name': None,
#     'IRWIN ID': '{5E0922CD-59F0-40AE-B38B-96C556E09B21}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '7096378.4609375',
#     'Shape__Length': '13992.2747564857',
#     'rank': 0.057308756},
#    {'_id': 2824,
#     'OBJECTID': '2824',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'ESR',
#     'Fire Name': 'HARKIN',
#     'Local Incident Number': '00001704',
#     'Alarm Date': '6/28/2017 12:00:00 AM',
#     'Containment Date': '6/28/2017 12:00:00 AM',
#     'Cause': '4',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.568609',
#     'Comments': 'K3JJ.  ',
#     'Complex Name': None,
#     'IRWIN ID': '{52A10DF9-1856-463C-9026-F2E0CA972B75}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '16292.29296875',
#     'Shape__Length': '681.926849370128',
#     'rank': 0.057308756},
#    {'_id': 2825,
#     'OBJECTID': '2825',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LMU',
#     'Fire Name': 'JONES',
#     'Local Incident Number': '00000268',
#     'Alarm Date': '6/3/2017 12:00:00 AM',
#     'Containment Date': '6/3/2017 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '42.07929',
#     'Comments': 'K1F9.  ',
#     'Complex Name': None,
#     'IRWIN ID': '{DD6A07B8-BC55-4FA2-82D5-2F1B01EDCFE9}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '302983.40234375',
#     'Shape__Length': '2977.88526006443',
#     'rank': 0.057308756},
#    {'_id': 2360,
#     'OBJECTID': '2360',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'ORC',
#     'Fire Name': ' ',
#     'Local Incident Number': '17093759',
#     'Alarm Date': '8/27/2017 12:00:00 AM',
#     'Containment Date': '8/27/2017 12:00:00 AM',
#     'Cause': '8',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.1167619',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '681.02734375',
#     'Shape__Length': '151.357575440706',
#     'rank': 0.057308756},
#    {'_id': 2826,
#     'OBJECTID': '2826',
#     'Year': '2017',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'MDF',
#     'Fire Name': 'LAKE',
#     'Local Incident Number': '00000794',
#     'Alarm Date': '7/27/2017 12:00:00 AM',
#     'Containment Date': '8/30/2017 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4665.485',
#     'Comments': None,
#     'Complex Name': 'Modoc July Complex (K7YC)',
#     'IRWIN ID': '{59B6A762-648C-4A2B-A4EB-0CD056D2308A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '34001990.9609375',
#     'Shape__Length': '50390.5345973264',
#     'rank': 0.057308756}],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'OBJECTID', 'type': 'text'},
#    {'id': 'Year', 'type': 'text'},
#    {'id': 'State', 'type': 'text'},
#    {'id': 'Agency', 'type': 'text'},
#    {'id': 'Unit ID', 'type': 'text'},
#    {'id': 'Fire Name', 'type': 'text'},
#    {'id': 'Local Incident Number', 'type': 'text'},
#    {'id': 'Alarm Date', 'type': 'text'},
#    {'id': 'Containment Date', 'type': 'text'},
#    {'id': 'Cause', 'type': 'text'},
#    {'id': 'Collection Method', 'type': 'text'},
#    {'id': 'Management Objective', 'type': 'text'},
#    {'id': 'GIS Calculated Acres', 'type': 'text'},
#    {'id': 'Comments', 'type': 'text'},
#    {'id': 'Complex Name', 'type': 'text'},
#    {'id': 'IRWIN ID', 'type': 'text'},
#    {'id': 'Fire Number (historical use)', 'type': 'text'},
#    {'id': 'Complex ID', 'type': 'text'},
#    {'id': 'DECADES', 'type': 'text'},
#    {'id': 'Shape__Area', 'type': 'text'},
#    {'id': 'Shape__Length', 'type': 'text'},
#    {'id': 'rank', 'type': 'float'}],
#   '_links': {'start': '/api/3/action/datastore_search?limit=1000&q=2017&resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991',
#    'next': '/api/3/action/datastore_search?limit=1000&q=2017&resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991&offset=1000'},
#   'total': 609,
#   'total_was_estimated': False}}

# %%
df = pd.DataFrame(response['result']['records'])
df_2017 = df.loc[df['Year'] == f'{str(year)}']
columns_to_keep = ['Year', 'Alarm Date','Containment Date','Cause','GIS Calculated Acres']
columns_to_drop = [col for col in df_2017.columns if col not in columns_to_keep]
df_2017 = df_2017.drop(columns=columns_to_drop)
df_2017 = df_2017.dropna (subset = ["Containment Date"])
df_2017.head()
# Out:
#    Year             Alarm Date       Containment Date Cause  \
# 0  2017  10/9/2017 12:00:00 AM  10/9/2017 12:00:00 AM    11
# 1  2017  9/11/2017 12:00:00 AM  9/11/2017 12:00:00 AM     1
# 3  2017  9/19/2017 12:00:00 AM  9/19/2017 12:00:00 AM    11
# 4  2017  8/31/2017 12:00:00 AM  8/31/2017 12:00:00 AM    14
# 5  2017  5/23/2017 12:00:00 AM  5/24/2017 12:00:00 AM    14
#
#   GIS Calculated Acres
# 0             130.2357
# 1              59.3685
# 3             38.80263
# 4           0.02271913
# 5             10.04382

# %%
df_2017['Alarm Date'] = [dt.replace(' 12:00:00 AM', '') for dt in df_2017['Alarm Date']]
df_2017['Containment Date'] = [str(item) for item in df_2017['Containment Date']]
df_2017['Containment Date'] = [dt.replace(' 12:00:00 AM', '') for dt in df_2017['Containment Date']]
df_2017.head()
# Out:
#    Year Alarm Date Containment Date Cause GIS Calculated Acres
# 0  2017  10/9/2017        10/9/2017    11             130.2357
# 1  2017  9/11/2017        9/11/2017     1              59.3685
# 3  2017  9/19/2017        9/19/2017    11             38.80263
# 4  2017  8/31/2017        8/31/2017    14           0.02271913
# 5  2017  5/23/2017        5/24/2017    14             10.04382

# %%
df_2017 = df_2017.rename(columns={'Cause': 'Cause #'})
df_2017['Cause'] = ''
df_2017['Cause #'] = df_2017['Cause #'].astype(int)
def map_cause_to_meaning(i):
    if i == 1:
        return 'Lightning'
    elif i == 2:
        return 'Equipment Use'
    elif i == 3:
        return 'Smoking'
    elif i == 4:
        return 'Campfire'
    elif i == 5:
        return 'Debris'
    elif i == 6:
        return 'Railroad'
    elif i == 7:
        return 'Arson'
    elif i == 8:
        return 'Playing with fire'
    elif i == 9:
        return 'Miscellaneous'
    elif i == 10:
        return 'Vehicle'
    elif i == 11:
        return 'Powerline'
    elif i == 12:
        return 'Firefighter Training'
    elif i == 13:
        return 'Non-Firefighter Training'
    elif i == 14:
        return 'Unknown / Unidentified'
    elif i == 15:
        return 'Structure'
    elif i == 16:
        return 'Aircraft'
    elif i == 18:
        return 'Escaped Prescribed Burn'
    elif i == 19:
        return 'Illegal Alien Campfire'
    else:
        return 'N/A'
df_2017['Cause'] = df_2017['Cause #'].apply(map_cause_to_meaning)
df_2017.head()
# Out:
#    Year Alarm Date Containment Date  Cause # GIS Calculated Acres  \
# 0  2017  10/9/2017        10/9/2017       11             130.2357
# 1  2017  9/11/2017        9/11/2017        1              59.3685
# 3  2017  9/19/2017        9/19/2017       11             38.80263
# 4  2017  8/31/2017        8/31/2017       14           0.02271913
# 5  2017  5/23/2017        5/24/2017       14             10.04382
#
#                     Cause
# 0               Powerline
# 1               Lightning
# 3               Powerline
# 4  Unknown / Unidentified
# 5  Unknown / Unidentified

# %%
df_2017.to_csv("outputs/fires_2017.csv",
                  encoding="utf-8", index=False, header=True)

# %%
# Attempt to convert 'Alarm Date' to datetime, coercing errors
df_2017['Alarm Date'] = pd.to_datetime(df_2017['Alarm Date'], errors='coerce')

# Display rows with invalid dates
invalid_dates = df_2017[df_2017['Alarm Date'].isna()]
print(invalid_dates)

# Continue with the processing
df_byalarm = df_2017.sort_values(by='Alarm Date').reset_index()
df_byalarm.head()
# Out:
# Empty DataFrame
# Columns: [Year, Alarm Date, Containment Date, Cause #, GIS Calculated Acres, Cause]
# Index: []
#    index  Year Alarm Date Containment Date  Cause # GIS Calculated Acres  \
# 0    132  2017 2017-01-30        1/30/2017       14          0.003896726
# 1     68  2017 2017-02-14        2/14/2017        5              16.0521
# 2    521  2017 2017-03-08         4/8/2017       11               33.345
# 3    522  2017 2017-03-08         8/8/2017       10             53.36273
# 4    331  2017 2017-03-26         4/1/2017       14             66.99863
#
#                     Cause
# 0  Unknown / Unidentified
# 1                  Debris
# 2               Powerline
# 3                 Vehicle
# 4  Unknown / Unidentified

# %%
earliest_fire = df_byalarm['Alarm Date'][0]
earliest_fire
# Out:
# Timestamp('2017-01-30 00:00:00')

# %%
# Convert 'Containment Date' to datetime, coercing errors
df_2017['Containment Date'] = pd.to_datetime(df_2017['Containment Date'], errors='coerce')

# Drop rows with invalid 'Containment Date'
df_2017_filtered = df_2017.dropna(subset=['Containment Date'])

# Now you can sort and process the DataFrame as needed
df_bycontainment = df_2017_filtered.sort_values(by='Containment Date', ascending=False).reset_index(drop=True)
latest_containment = df_bycontainment['Containment Date'].iloc[0]

df_bycontainment.head()
# Out:
#    Year Alarm Date Containment Date  Cause # GIS Calculated Acres  \
# 0  2017 2017-08-20       2018-01-15        1               48.382
# 1  2017 2017-08-12       2018-01-15        1             31.87081
# 2  2017 2017-12-04       2018-01-12        9             281790.9
# 3  2017 2017-08-10       2018-01-09        1             32893.26
# 4  2017 2017-12-07       2017-12-24       14             4080.615
#
#                     Cause
# 0               Lightning
# 1               Lightning
# 2           Miscellaneous
# 3               Lightning
# 4  Unknown / Unidentified

# %%
latest_containment
# Out:
# Timestamp('2018-01-15 00:00:00')

# %%
output_path = os.path.join("outputs", "timeline_dates_2017.csv")
with open(output_path, 'w') as csvfile:

    # Initialize csv.writer
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Write the first row (column headers)
    csvwriter.writerow(['Title', 'Date'])
    csvwriter.writerow(['Earliest Fire', earliest_fire])

    # Write the second row
    csvwriter.writerow(['Latest Containment', latest_containment])
