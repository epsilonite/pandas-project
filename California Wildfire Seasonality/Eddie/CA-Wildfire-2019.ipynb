# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
from datetime import datetime
import os
import csv

# %%
# Save config information.
url = "https://data.ca.gov/api/3/action/datastore_search?resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991&"

# Build partial query URL
limit = 1000
year = 2019
query_url = f"{url}&limit={limit}&q={year}"
response = requests.get(query_url).json()
response
# Out:
# {'help': 'https://data.ca.gov/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 1000,
#   'q': '2019',
#   'records_format': 'objects',
#   'resource_id': 'd73ee828-c2c6-485c-91dc-c26bd9ce3991',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1662,
#     'OBJECTID': '1662',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'HTF',
#     'Fire Name': 'TAMARACK',
#     'Local Incident Number': '00030272',
#     'Alarm Date': None,
#     'Containment Date': None,
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '67.21748',
#     'Comments': 'chanley_nifc;from EGP REST, in July',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '444603.4921875',
#     'Shape__Length': '3070.19085492208',
#     'rank': 0.057308756},
#    {'_id': 1497,
#     'OBJECTID': '1497',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'GROVE',
#     'Local Incident Number': '01948217',
#     'Alarm Date': '11/15/2019 12:00:00 AM',
#     'Containment Date': '11/15/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '14.53588',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '89493.0703125',
#     'Shape__Length': '1852.82075120804',
#     'rank': 0.057308756},
#    {'_id': 1663,
#     'OBJECTID': '1663',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'ORC',
#     'Fire Name': 'BLUE DIAMOND',
#     'Local Incident Number': '19059616',
#     'Alarm Date': '5/29/0219 12:00:00 AM',
#     'Containment Date': '5/29/0219 12:00:00 AM',
#     'Cause': '16',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.29694',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '13487.25',
#     'Shape__Length': '1125.7974604101',
#     'rank': 0.057308756},
#    {'_id': 1664,
#     'OBJECTID': '1664',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'ORC',
#     'Fire Name': 'BELLA COLLINA GOLF COURSE SCL ',
#     'Local Incident Number': '19085271',
#     'Alarm Date': '7/31/2019 12:00:00 AM',
#     'Containment Date': '7/31/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3.76396',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '21940.62109375',
#     'Shape__Length': '739.658615644226',
#     'rank': 0.057308756},
#    {'_id': 1484,
#     'OBJECTID': '1484',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'MARIA',
#     'Local Incident Number': '00090135',
#     'Alarm Date': '10/31/2019 12:00:00 AM',
#     'Containment Date': '11/5/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10042.46',
#     'Comments': 'Maria IMT, 11/3/2019 2130hrs',
#     'Complex Name': None,
#     'IRWIN ID': '{A62F7CDE-CCBA-44B9-8F10-EEE18946A218}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '59718543.7578125',
#     'Shape__Length': '66055.5952608772',
#     'rank': 0.057308756},
#    {'_id': 1485,
#     'OBJECTID': '1485',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'EASY',
#     'Local Incident Number': '00089158',
#     'Alarm Date': '10/30/2019 12:00:00 AM',
#     'Containment Date': '11/13/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1806.234',
#     'Comments': 'multiple perimeters',
#     'Complex Name': None,
#     'IRWIN ID': '{FC96A780-3096-487F-97EB-69D6CB7DC33E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '10729257.6679688',
#     'Shape__Length': '30918.4361655625',
#     'rank': 0.057308756},
#    {'_id': 1486,
#     'OBJECTID': '1486',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'OLIVAS',
#     'Local Incident Number': '00082263',
#     'Alarm Date': '10/11/2019 12:00:00 AM',
#     'Containment Date': '10/13/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '171.4183',
#     'Comments': 'Multiple perimeters',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1017353.609375',
#     'Shape__Length': '6473.67914924245',
#     'rank': 0.057308756},
#    {'_id': 1487,
#     'OBJECTID': '1487',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'SOUTH',
#     'Local Incident Number': '00055688',
#     'Alarm Date': '7/14/2019 12:00:00 AM',
#     'Containment Date': '7/15/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '131.3172',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{BECDF134-4267-4842-93EB-CAA0D14989CC}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '781530.203125',
#     'Shape__Length': '3413.74925332906',
#     'rank': 0.057308756},
#    {'_id': 1488,
#     'OBJECTID': '1488',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'VNC',
#     'Fire Name': 'POTRERO',
#     'Local Incident Number': '00059442',
#     'Alarm Date': '7/26/2019 12:00:00 AM',
#     'Containment Date': '7/27/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.11976',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E5DD9F89-1691-4E61-9A03-D1F43E32BC55}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '65878.5625',
#     'Shape__Length': '1302.49423980605',
#     'rank': 0.057308756},
#    {'_id': 1489,
#     'OBJECTID': '1489',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BTU',
#     'Fire Name': 'SWEDES',
#     'Local Incident Number': '00010594',
#     'Alarm Date': '9/6/2019 12:00:00 AM',
#     'Containment Date': '9/9/2019 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '510.1355',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{D74014CD-F442-48BC-8D7D-AC16E0AC0203}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '3468134.78515625',
#     'Shape__Length': '11259.8647320422',
#     'rank': 0.057308756},
#    {'_id': 1490,
#     'OBJECTID': '1490',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'BTU',
#     'Fire Name': 'FORBESTOWN',
#     'Local Incident Number': '00010635',
#     'Alarm Date': '9/6/2019 12:00:00 AM',
#     'Containment Date': '9/16/2019 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '57.4474',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A21ACD03-412E-49A0-BFB9-9F4A9E8DA230}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '390788.8828125',
#     'Shape__Length': '2715.22594305891',
#     'rank': 0.057308756},
#    {'_id': 1491,
#     'OBJECTID': '1491',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'TUU',
#     'Fire Name': 'CREEK_4',
#     'Local Incident Number': '00000684',
#     'Alarm Date': '8/31/2019 12:00:00 AM',
#     'Containment Date': '9/6/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '754.4257',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A70BC41C-7ABC-47F8-85A3-C5B86339034E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '4726905.2421875',
#     'Shape__Length': '11193.4591287053',
#     'rank': 0.057308756},
#    {'_id': 1692,
#     'OBJECTID': '1692',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'SLU',
#     'Fire Name': 'TRACY',
#     'Local Incident Number': '00006901',
#     'Alarm Date': '5/27/2019 12:00:00 AM',
#     'Containment Date': '5/27/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '38.42611',
#     'Comments': 'Electrical Power',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '234426.73046875',
#     'Shape__Length': '1962.1233120954',
#     'rank': 0.057308756},
#    {'_id': 1492,
#     'OBJECTID': '1492',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'SBC',
#     'Fire Name': 'MCMURRAY',
#     'Local Incident Number': '00011619',
#     'Alarm Date': '9/10/2019 12:00:00 AM',
#     'Containment Date': '9/14/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '355.3229',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8080CE8F-1263-4415-8173-F82576A4E409}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2129982.6640625',
#     'Shape__Length': '13024.5537905464',
#     'rank': 0.057308756},
#    {'_id': 1493,
#     'OBJECTID': '1493',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'SBC',
#     'Fire Name': 'REAL',
#     'Local Incident Number': '00013465',
#     'Alarm Date': '10/17/2019 12:00:00 AM',
#     'Containment Date': '10/21/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '3',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '420.6586',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{23C1997D-281E-4F50-822F-0A0CC56FFC7C}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2510906.6640625',
#     'Shape__Length': '8608.85786435362',
#     'rank': 0.057308756},
#    {'_id': 1494,
#     'OBJECTID': '1494',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'SBC',
#     'Fire Name': 'BAR',
#     'Local Incident Number': None,
#     'Alarm Date': '11/13/2019 12:00:00 AM',
#     'Containment Date': '11/13/2019 12:00:00 AM',
#     'Cause': '18',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '51.6265',
#     'Comments': 'Slopover on Bar M VMP',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '309784.66015625',
#     'Shape__Length': '3828.80681807058',
#     'rank': 0.057308756},
#    {'_id': 1495,
#     'OBJECTID': '1495',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'SBC',
#     'Fire Name': 'SWEENEY',
#     'Local Incident Number': '00010380',
#     'Alarm Date': '8/14/2019 12:00:00 AM',
#     'Containment Date': '8/14/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '16.98027',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{748CA915-187E-4072-BE0C-D0987933DDAC}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '101744.9375',
#     'Shape__Length': '1363.54399058278',
#     'rank': 0.057308756},
#    {'_id': 1496,
#     'OBJECTID': '1496',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'VULCAN',
#     'Local Incident Number': '01917674',
#     'Alarm Date': '5/3/2019 12:00:00 AM',
#     'Containment Date': '5/3/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '169.9031',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{5FBF49F2-4B52-4A6A-B513-1E1DE8F4E0E8}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1027203.46875',
#     'Shape__Length': '5634.19984679971',
#     'rank': 0.057308756},
#    {'_id': 1498,
#     'OBJECTID': '1498',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'ENTRANCE',
#     'Local Incident Number': '01921595',
#     'Alarm Date': '5/30/2019 12:00:00 AM',
#     'Containment Date': '5/30/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '53.31026',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '326539.3828125',
#     'Shape__Length': '2563.56167606098',
#     'rank': 0.057308756},
#    {'_id': 1499,
#     'OBJECTID': '1499',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'BARREL',
#     'Local Incident Number': '01919623',
#     'Alarm Date': '5/16/2019 12:00:00 AM',
#     'Containment Date': '5/16/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '55.86135',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '343362.58203125',
#     'Shape__Length': '3353.22617724059',
#     'rank': 0.057308756},
#    {'_id': 1500,
#     'OBJECTID': '1500',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'KECKS',
#     'Local Incident Number': '01917930',
#     'Alarm Date': '5/5/2019 12:00:00 AM',
#     'Containment Date': '5/5/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '13.33649',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '81958.83203125',
#     'Shape__Length': '1904.12608607301',
#     'rank': 0.057308756},
#    {'_id': 1501,
#     'OBJECTID': '1501',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'CORCORAN',
#     'Local Incident Number': '01940150',
#     'Alarm Date': '9/24/2019 12:00:00 AM',
#     'Containment Date': '9/24/2019 12:00:00 AM',
#     'Cause': '3',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.897731',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '17826.3203125',
#     'Shape__Length': '1283.32964269808',
#     'rank': 0.057308756},
#    {'_id': 1502,
#     'OBJECTID': '1502',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'PHILLIPS',
#     'Local Incident Number': '01945610',
#     'Alarm Date': '10/30/2019 12:00:00 AM',
#     'Containment Date': '10/30/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.653334',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '28577.61328125',
#     'Shape__Length': '979.738635813727',
#     'rank': 0.057308756},
#    {'_id': 1503,
#     'OBJECTID': '1503',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'RIDGE',
#     'Local Incident Number': '01940848',
#     'Alarm Date': '9/29/2019 12:00:00 AM',
#     'Containment Date': '9/29/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '38.80555',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '234588.3828125',
#     'Shape__Length': '2135.8966202936',
#     'rank': 0.057308756},
#    {'_id': 1504,
#     'OBJECTID': '1504',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'MESA',
#     'Local Incident Number': '01931668',
#     'Alarm Date': '7/31/2019 12:00:00 AM',
#     'Containment Date': '8/1/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '227.0095',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{1B208787-FA65-4006-AF92-742AA73BDD3B}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1392801.26171875',
#     'Shape__Length': '4884.86176516725',
#     'rank': 0.057308756},
#    {'_id': 1505,
#     'OBJECTID': '1505',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'KRN',
#     'Fire Name': 'WHITE',
#     'Local Incident Number': '01942085',
#     'Alarm Date': '10/7/2019 12:00:00 AM',
#     'Containment Date': '10/8/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '61.07991',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '374630.30859375',
#     'Shape__Length': '3731.08497591195',
#     'rank': 0.057308756},
#    {'_id': 1506,
#     'OBJECTID': '1506',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'OAK',
#     'Local Incident Number': '00016101',
#     'Alarm Date': '9/7/2019 12:00:00 AM',
#     'Containment Date': '9/10/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '53.11696',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{06856648-E5E2-4AAF-9973-A6BF22E459E6}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '355945.7421875',
#     'Shape__Length': '2300.32742050771',
#     'rank': 0.057308756},
#    {'_id': 1507,
#     'OBJECTID': '1507',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'EAGLE',
#     'Local Incident Number': '00020533',
#     'Alarm Date': '11/4/2019 12:00:00 AM',
#     'Containment Date': '11/4/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '73.55055',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E5A830FA-CBF3-4106-93FC-EABA8F030E7E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '494834.80859375',
#     'Shape__Length': '4075.06240106921',
#     'rank': 0.057308756},
#    {'_id': 1508,
#     'OBJECTID': '1508',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'KINCADE',
#     'Local Incident Number': '00019376',
#     'Alarm Date': '10/23/2019 12:00:00 AM',
#     'Containment Date': '11/10/2019 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '77762.14',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{FE8285DB-86DE-4F8C-B54E-3FE4A9F2182A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '517112590.625',
#     'Shape__Length': '238568.85640898',
#     'rank': 0.057308756},
#    {'_id': 1509,
#     'OBJECTID': '1509',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'AMERICAN',
#     'Local Incident Number': '00018056',
#     'Alarm Date': '10/6/2019 12:00:00 AM',
#     'Containment Date': '10/7/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '526.8578',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{15142569-469A-4220-A8CE-0105F7687A81}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '3455730.1328125',
#     'Shape__Length': '8792.30789103913',
#     'rank': 0.057308756},
#    {'_id': 1510,
#     'OBJECTID': '1510',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'CANYON',
#     'Local Incident Number': '00012823',
#     'Alarm Date': '7/22/2019 12:00:00 AM',
#     'Containment Date': '7/25/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '48.00141',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{6E449655-19AE-4209-B80E-908344047866}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '317321.45703125',
#     'Shape__Length': '2459.13154567684',
#     'rank': 0.057308756},
#    {'_id': 1511,
#     'OBJECTID': '1511',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'OLIVE',
#     'Local Incident Number': '00010653',
#     'Alarm Date': '6/19/2019 12:00:00 AM',
#     'Containment Date': '6/20/2019 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '16.01936',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{DC846533-0FFF-4D0D-8374-E95C260155A8}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '105923.390625',
#     'Shape__Length': '1659.02243451978',
#     'rank': 0.057308756},
#    {'_id': 1512,
#     'OBJECTID': '1512',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'BACHELOR',
#     'Local Incident Number': '00016252',
#     'Alarm Date': '9/9/2019 12:00:00 AM',
#     'Containment Date': '9/9/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '15.83755',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{5CD0535B-7748-45C3-AB0F-9BF1193D532E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '106871.8671875',
#     'Shape__Length': '1439.19956540516',
#     'rank': 0.057308756},
#    {'_id': 1513,
#     'OBJECTID': '1513',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'GLASS',
#     'Local Incident Number': '00015917',
#     'Alarm Date': '9/4/2019 12:00:00 AM',
#     'Containment Date': '9/4/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '23.91912',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{2E36F157-65B9-4E25-A094-BE6F86489650}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '160123.86328125',
#     'Shape__Length': '3201.10293101531',
#     'rank': 0.057308756},
#    {'_id': 1514,
#     'OBJECTID': '1514',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'LNU',
#     'Fire Name': 'SAND',
#     'Local Incident Number': '00009880',
#     'Alarm Date': '6/8/2019 12:00:00 AM',
#     'Containment Date': '6/13/2019 12:00:00 AM',
#     'Cause': '1',
#     'Collection Method': '2',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2422.018',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{531392A4-947E-4C00-A43E-188F93D7F37D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '16208267.4921875',
#     'Shape__Length': '29141.5665393798',
#     'rank': 0.057308756},
#    {'_id': 1515,
#     'OBJECTID': '1515',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'CAMINO',
#     'Local Incident Number': '00016167',
#     'Alarm Date': '11/2/2019 12:00:00 AM',
#     'Containment Date': '11/2/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.7218916',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{23377CE0-FA35-4511-A2DF-1756F58FA38E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '4188.984375',
#     'Shape__Length': '344.60266709326',
#     'rank': 0.057308756},
#    {'_id': 1516,
#     'OBJECTID': '1516',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'CRESTWOOD',
#     'Local Incident Number': '00016171',
#     'Alarm Date': '11/2/2019 12:00:00 AM',
#     'Containment Date': '11/2/2019 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '31.55482',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{046870C2-F13A-4DA3-9719-4A648B1DE97D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '180842.55078125',
#     'Shape__Length': '2845.92839518442',
#     'rank': 0.057308756},
#    {'_id': 1517,
#     'OBJECTID': '1517',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'DEHESA 11',
#     'Local Incident Number': '00014018',
#     'Alarm Date': '9/24/2019 12:00:00 AM',
#     'Containment Date': '10/2/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '225.646',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8E04E0FE-0F30-4A73-BFD4-B9327D5F7799}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1295359.37109375',
#     'Shape__Length': '5995.59162867235',
#     'rank': 0.057308756},
#    {'_id': 1518,
#     'OBJECTID': '1518',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'AIRPORT',
#     'Local Incident Number': '00012538',
#     'Alarm Date': '8/28/2019 12:00:00 AM',
#     'Containment Date': '8/28/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.677516',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{9C33BAE6-A305-47CB-8F35-8AD8040EC428}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '9740.79296875',
#     'Shape__Length': '397.073067979172',
#     'rank': 0.057308756},
#    {'_id': 1519,
#     'OBJECTID': '1519',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'PAUMA 4',
#     'Local Incident Number': '00008223',
#     'Alarm Date': '6/10/2019 12:00:00 AM',
#     'Containment Date': '6/24/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '22.0214',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{AD0BBA0E-1450-4022-9E7C-6F61C3DF21A0}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '127906.6328125',
#     'Shape__Length': '1783.64002629149',
#     'rank': 0.057308756},
#    {'_id': 1520,
#     'OBJECTID': '1520',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'DEHESA 8',
#     'Local Incident Number': '00010859',
#     'Alarm Date': '7/28/2019 12:00:00 AM',
#     'Containment Date': '8/2/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '141.9548',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{EF56C588-6843-4063-9715-C98A41F72A1C}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '815045.84375',
#     'Shape__Length': '4998.24649698377',
#     'rank': 0.057308756},
#    {'_id': 1521,
#     'OBJECTID': '1521',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'OTAY 11',
#     'Local Incident Number': '00009151',
#     'Alarm Date': '6/29/2019 12:00:00 AM',
#     'Containment Date': '6/30/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '27.51976',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{8D7A370B-9451-4F14-BDEE-8E74C2FA39EE}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '157390.1640625',
#     'Shape__Length': '1697.84602791527',
#     'rank': 0.057308756},
#    {'_id': 1522,
#     'OBJECTID': '1522',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'VISTA 5',
#     'Local Incident Number': '00010198',
#     'Alarm Date': '7/17/2019 12:00:00 AM',
#     'Containment Date': '7/18/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '16.69558',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{A151678A-5F3E-466C-BCB3-59F5CA6B86D7}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '95880.93359375',
#     'Shape__Length': '1569.03284204238',
#     'rank': 0.057308756},
#    {'_id': 1523,
#     'OBJECTID': '1523',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'GREEN 3',
#     'Local Incident Number': '00014697',
#     'Alarm Date': '11/6/2019 12:00:00 AM',
#     'Containment Date': '11/7/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '6.311408',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{91B31D98-6838-40E7-B3A3-7B3642E7B09E}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '36342.8671875',
#     'Shape__Length': '972.685179511087',
#     'rank': 0.057308756},
#    {'_id': 1524,
#     'OBJECTID': '1524',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'MORRETTI',
#     'Local Incident Number': '00012202',
#     'Alarm Date': '8/22/2019 12:00:00 AM',
#     'Containment Date': '8/22/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.231062',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{92B13246-09E3-410F-81D8-9C5FDFBB7239}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '7137.69140625',
#     'Shape__Length': '360.618294300639',
#     'rank': 0.057308756},
#    {'_id': 1525,
#     'OBJECTID': '1525',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'GATE',
#     'Local Incident Number': '00012198',
#     'Alarm Date': '8/22/2019 12:00:00 AM',
#     'Containment Date': '8/23/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '7.226138',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{477F31B1-2D07-42B1-801A-E1C1387270A1}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '41972.58203125',
#     'Shape__Length': '1140.92657512359',
#     'rank': 0.057308756},
#    {'_id': 1526,
#     'OBJECTID': '1526',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'MILLER 2',
#     'Local Incident Number': '00015748',
#     'Alarm Date': '10/25/2019 12:00:00 AM',
#     'Containment Date': '10/27/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '29.26041',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{214BECAF-3E70-4B70-AD73-A89D1C962E0D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '169825.44140625',
#     'Shape__Length': '2880.47828449062',
#     'rank': 0.057308756},
#    {'_id': 1527,
#     'OBJECTID': '1527',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'BORDER 6',
#     'Local Incident Number': '00009892',
#     'Alarm Date': '7/12/2019 12:00:00 AM',
#     'Containment Date': '7/15/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '467.1911',
#     'Comments': '116 acres in US 400+- in Mexico ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2669324.1484375',
#     'Shape__Length': '9529.82404969859',
#     'rank': 0.057308756},
#    {'_id': 1528,
#     'OBJECTID': '1528',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'WILLOWS 3',
#     'Local Incident Number': '00014088',
#     'Alarm Date': '9/25/2019 12:00:00 AM',
#     'Containment Date': '9/25/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '57.42204',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{F2466BC9-F5E3-45DB-9A62-50B7CA823C85}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '330365.3984375',
#     'Shape__Length': '4096.48555383252',
#     'rank': 0.057308756},
#    {'_id': 1529,
#     'OBJECTID': '1529',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'GASOLINE',
#     'Local Incident Number': '00007586',
#     'Alarm Date': '5/29/2019 12:00:00 AM',
#     'Containment Date': '5/30/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '29.53726',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '169093.51953125',
#     'Shape__Length': '2252.18383504323',
#     'rank': 0.057308756},
#    {'_id': 1530,
#     'OBJECTID': '1530',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'BORDER',
#     'Local Incident Number': '00006784',
#     'Alarm Date': '5/13/2019 12:00:00 AM',
#     'Containment Date': '5/19/2019 12:00:00 AM',
#     'Cause': '5',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '23.3554',
#     'Comments': '17.5 on the US side 5.8 on the Mexico side',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '133420.37890625',
#     'Shape__Length': '2590.48549167107',
#     'rank': 0.057308756},
#    {'_id': 1531,
#     'OBJECTID': '1531',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'SCOUT',
#     'Local Incident Number': '00014643',
#     'Alarm Date': '10/5/2019 12:00:00 AM',
#     'Containment Date': '10/5/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '25.53614',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{6D4D9691-09EE-4CCA-900B-B4A648260927}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '148042.72265625',
#     'Shape__Length': '2667.35595982424',
#     'rank': 0.057308756},
#    {'_id': 1532,
#     'OBJECTID': '1532',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'COPPER',
#     'Local Incident Number': '00016047',
#     'Alarm Date': '10/30/2019 12:00:00 AM',
#     'Containment Date': '11/1/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '371.3559',
#     'Comments': 'WFDSS -151 acres in US, 220 in Mexico',
#     'Complex Name': None,
#     'IRWIN ID': '{AC0266E5-20DF-4D91-92DC-BC439D9A88AF}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '2121411.33984375',
#     'Shape__Length': '7206.4684806568',
#     'rank': 0.057308756},
#    {'_id': 1533,
#     'OBJECTID': '1533',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'BORDER 9',
#     'Local Incident Number': '00011839',
#     'Alarm Date': '8/15/2019 12:00:00 AM',
#     'Containment Date': '8/16/2019 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '67.37229',
#     'Comments': '67 acres  in US',
#     'Complex Name': None,
#     'IRWIN ID': '{AC6A4023-3940-4CED-9C05-541579D2202D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '384982.90234375',
#     'Shape__Length': '3324.02816644846',
#     'rank': 0.057308756},
#    {'_id': 1534,
#     'OBJECTID': '1534',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'BORDER 10',
#     'Local Incident Number': '00012378',
#     'Alarm Date': '8/25/2019 12:00:00 AM',
#     'Containment Date': '8/28/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '11.86247',
#     'Comments': '13.2 acres in Mexico 11.8 U.S. ',
#     'Complex Name': None,
#     'IRWIN ID': '{D09ED41A-B447-4393-BBA6-B5A33493F4D1}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '67767.5546875',
#     'Shape__Length': '1262.91464526713',
#     'rank': 0.057308756},
#    {'_id': 1535,
#     'OBJECTID': '1535',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'MVU',
#     'Fire Name': 'SAWDAY',
#     'Local Incident Number': '00015731',
#     'Alarm Date': '10/25/2019 12:00:00 AM',
#     'Containment Date': '10/28/2019 12:00:00 AM',
#     'Cause': '15',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '101.1678',
#     'Comments': ' ',
#     'Complex Name': None,
#     'IRWIN ID': '{885384BC-9F60-4A0B-A777-37035140EE9C}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '584374.52734375',
#     'Shape__Length': '4226.7676542676',
#     'rank': 0.057308756},
#    {'_id': 1536,
#     'OBJECTID': '1536',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'BROWNS',
#     'Local Incident Number': '00023326',
#     'Alarm Date': '8/2/2019 12:00:00 AM',
#     'Containment Date': '8/2/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '84.32344',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{D3FBD90E-6C27-4867-AEF8-C6D95283AE85}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '556061.390625',
#     'Shape__Length': '3606.92786332518',
#     'rank': 0.057308756},
#    {'_id': 1537,
#     'OBJECTID': '1537',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'CARSON',
#     'Local Incident Number': '00023015',
#     'Alarm Date': '7/30/2019 12:00:00 AM',
#     'Containment Date': '7/30/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '13.1878',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{7210266F-4994-4569-8CD4-1FEFC65DC358}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '87888.8671875',
#     'Shape__Length': '1466.32215764581',
#     'rank': 0.057308756},
#    {'_id': 1538,
#     'OBJECTID': '1538',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'CHAPARRAL',
#     'Local Incident Number': '00029708',
#     'Alarm Date': '9/29/2019 12:00:00 AM',
#     'Containment Date': '9/29/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '21.85111',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E7DACE86-2715-4B2A-862B-F1D483AA5D8D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '144765.12890625',
#     'Shape__Length': '2389.70042155695',
#     'rank': 0.057308756},
#    {'_id': 1539,
#     'OBJECTID': '1539',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'COULTER',
#     'Local Incident Number': '00028812',
#     'Alarm Date': '9/21/2019 12:00:00 AM',
#     'Containment Date': '9/21/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '17.78828',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{95F26E4A-F33D-47F6-8392-6DD2B2C2946D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '117878.38671875',
#     'Shape__Length': '1692.28010526352',
#     'rank': 0.057308756},
#    {'_id': 1540,
#     'OBJECTID': '1540',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'COUNTRY',
#     'Local Incident Number': '00026999',
#     'Alarm Date': '9/3/2019 12:00:00 AM',
#     'Containment Date': '9/3/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '85.59669',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{24AF5B19-6264-4461-897B-4337B0C0EE27}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '572850.19140625',
#     'Shape__Length': '5463.74042764949',
#     'rank': 0.057308756},
#    {'_id': 1541,
#     'OBJECTID': '1541',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'ELECTRA',
#     'Local Incident Number': '00029257',
#     'Alarm Date': '9/25/2019 12:00:00 AM',
#     'Containment Date': '9/25/2019 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.23911',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{3A8BA702-AAA8-4E7F-8A2E-7A7E08DCA1B1}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '67449.08984375',
#     'Shape__Length': '1736.75197308159',
#     'rank': 0.057308756},
#    {'_id': 1542,
#     'OBJECTID': '1542',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'LIBERTY',
#     'Local Incident Number': '00026884',
#     'Alarm Date': '9/2/2019 12:00:00 AM',
#     'Containment Date': '9/2/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.66764',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{F34687AE-CB34-40AE-9A2B-233BD0D3551D}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '70145.51953125',
#     'Shape__Length': '1588.89663756157',
#     'rank': 0.057308756},
#    {'_id': 1543,
#     'OBJECTID': '1543',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'PATTERSON',
#     'Local Incident Number': '00024851',
#     'Alarm Date': '8/15/2019 12:00:00 AM',
#     'Containment Date': '8/15/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '34.91486',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '232061.703125',
#     'Shape__Length': '2336.71482963626',
#     'rank': 0.057308756},
#    {'_id': 1544,
#     'OBJECTID': '1544',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'AEU',
#     'Fire Name': 'VINTAGE',
#     'Local Incident Number': '00021136',
#     'Alarm Date': '7/14/2019 12:00:00 AM',
#     'Containment Date': '7/14/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2.438375',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{E98EB4D4-0910-4E59-BEA2-C84F6B85F774}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '16179.109375',
#     'Shape__Length': '557.883089677906',
#     'rank': 0.057308756},
#    {'_id': 1545,
#     'OBJECTID': '1545',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'FKU',
#     'Fire Name': 'DEER',
#     'Local Incident Number': '00008718',
#     'Alarm Date': '6/23/2019 12:00:00 AM',
#     'Containment Date': '6/26/2019 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '64.95156',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{4BBA1B0B-07CA-447B-B20B-D172971D9FDB}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '411319.15234375',
#     'Shape__Length': '3371.72960695997',
#     'rank': 0.057308756},
#    {'_id': 1546,
#     'OBJECTID': '1546',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'FKU',
#     'Fire Name': 'DEVIL',
#     'Local Incident Number': '00005520',
#     'Alarm Date': '4/24/2019 12:00:00 AM',
#     'Containment Date': '4/24/2019 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '50.13959',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '309407.84765625',
#     'Shape__Length': '3884.37175058198',
#     'rank': 0.057308756},
#    {'_id': 1547,
#     'OBJECTID': '1547',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'FKU',
#     'Fire Name': 'HILLS',
#     'Local Incident Number': '00007319',
#     'Alarm Date': '5/29/2019 12:00:00 AM',
#     'Containment Date': '6/1/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '120.6404',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{14DDC777-4FDA-44C9-9E1D-2EAF5F906671}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '760502.43359375',
#     'Shape__Length': '4204.88618552118',
#     'rank': 0.057308756},
#    {'_id': 1548,
#     'OBJECTID': '1548',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CDF',
#     'Unit ID': 'FKU',
#     'Fire Name': 'HORSE',
#     'Local Incident Number': '00012035',
#     'Alarm Date': '10/18/2019 12:00:00 AM',
# ...
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '10741.1953125',
#     'Shape__Length': '689.167979501876',
#     'rank': 0.057308756},
#    {'_id': 1783,
#     'OBJECTID': '1783',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': None,
#     'Fire Name': 'SWEETWATER',
#     'Local Incident Number': None,
#     'Alarm Date': '8/30/2019 12:00:00 AM',
#     'Containment Date': '8/30/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '17.72473',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '104740.82421875',
#     'Shape__Length': '1587.2649515162',
#     'rank': 0.057308756},
#    {'_id': 1784,
#     'OBJECTID': '1784',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'NPS',
#     'Unit ID': 'SMP',
#     'Fire Name': 'WENDY',
#     'Local Incident Number': '00000558',
#     'Alarm Date': '10/10/2019 12:00:00 AM',
#     'Containment Date': '10/14/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '80.3277',
#     'Comments': 'FRA Supression by VCFD County #82061',
#     'Complex Name': None,
#     'IRWIN ID': '{4AD07607-6B10-4581-B04E-11A959884F59}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '475817.93359375',
#     'Shape__Length': '3685.38674404999',
#     'rank': 0.057308756},
#    {'_id': 1785,
#     'OBJECTID': '1785',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'NPS',
#     'Unit ID': 'MNP',
#     'Fire Name': 'STAR',
#     'Local Incident Number': '00013598',
#     'Alarm Date': None,
#     'Containment Date': None,
#     'Cause': '14',
#     'Collection Method': '8',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '66.58718',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{9C57E040-EE4C-419E-9739-82A5E9308D4A}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '405174.078125',
#     'Shape__Length': '4777.04267187375',
#     'rank': 0.057308756},
#    {'_id': 1786,
#     'OBJECTID': '1786',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'LDF',
#     'Fire Name': 'SADDLE RIDGE',
#     'Local Incident Number': '00001582',
#     'Alarm Date': '10/10/2019 12:00:00 AM',
#     'Containment Date': '10/31/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '8799.325',
#     'Comments': 'shape from GEOMAC, dat from CAL FIRE web',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '52335530.796875',
#     'Shape__Length': '86547.4078324164',
#     'rank': 0.057308756},
#    {'_id': 1787,
#     'OBJECTID': '1787',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'LDF',
#     'Fire Name': 'PALISADES 2',
#     'Local Incident Number': '00000580',
#     'Alarm Date': '10/21/2019 12:00:00 AM',
#     'Containment Date': '10/21/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '45.09488',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '266559.3203125',
#     'Shape__Length': '2935.43326084543',
#     'rank': 0.057308756},
#    {'_id': 1788,
#     'OBJECTID': '1788',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'LDF',
#     'Fire Name': 'GETTY',
#     'Local Incident Number': '00001583',
#     'Alarm Date': '10/28/2019 12:00:00 AM',
#     'Containment Date': '11/5/2019 12:00:00 AM',
#     'Cause': '11',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '552.6332',
#     'Comments': 'Event Stand Perims, branches blew into powerline',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '3269037.859375',
#     'Shape__Length': '21590.3489548436',
#     'rank': 0.057308756},
#    {'_id': 1789,
#     'OBJECTID': '1789',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': None,
#     'Fire Name': 'OAK',
#     'Local Incident Number': None,
#     'Alarm Date': '10/28/2019 12:00:00 AM',
#     'Containment Date': '10/28/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '10.82971',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': '{2B5323E9-30FB-4ADC-8498-484BDB6D937F}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '64149.796875',
#     'Shape__Length': '1654.93744797812',
#     'rank': 0.057308756},
#    {'_id': 1790,
#     'OBJECTID': '1790',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'LAC',
#     'Fire Name': 'MUREAU',
#     'Local Incident Number': None,
#     'Alarm Date': '10/30/2019 12:00:00 AM',
#     'Containment Date': '10/30/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '7',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '5.9004',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '34952.75',
#     'Shape__Length': '963.071018828235',
#     'rank': 0.057308756},
#    {'_id': 1791,
#     'OBJECTID': '1791',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'LRA',
#     'Unit ID': 'LDF',
#     'Fire Name': 'BARHAM',
#     'Local Incident Number': '00000845',
#     'Alarm Date': '11/9/2019 12:00:00 AM',
#     'Containment Date': '11/10/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '72.63429',
#     'Comments': 'LACFD 0845',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '430190.96484375',
#     'Shape__Length': '5393.34937929385',
#     'rank': 0.057308756},
#    {'_id': 1792,
#     'OBJECTID': '1792',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'LPF',
#     'Fire Name': 'CAVE',
#     'Local Incident Number': '00002908',
#     'Alarm Date': '11/25/2019 12:00:00 AM',
#     'Containment Date': '12/14/2019 12:00:00 AM',
#     'Cause': '7',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '2597.293',
#     'Comments': 'Updated 2022: Ground truthing & aerial image interpretation',
#     'Complex Name': None,
#     'IRWIN ID': '{3821BA3B-B9A5-45D1-99FC-299B4B452049}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '15508726.171875',
#     'Shape__Length': '58908.296722205',
#     'rank': 0.057308756},
#    {'_id': 1793,
#     'OBJECTID': '1793',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'TNR',
#     'Fire Name': 'AGUA',
#     'Local Incident Number': '00021198',
#     'Alarm Date': '10/11/2019 12:00:00 AM',
#     'Containment Date': '10/12/2019 12:00:00 AM',
#     'Cause': '8',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '31.12859',
#     'Comments': 'MVD2',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '178311.8203125',
#     'Shape__Length': '2528.12167353709',
#     'rank': 0.057308756},
#    {'_id': 1794,
#     'OBJECTID': '1794',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'PLR',
#     'Fire Name': 'TRACK',
#     'Local Incident Number': '00000512',
#     'Alarm Date': '6/27/2019 12:00:00 AM',
#     'Containment Date': '6/27/2019 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '104.9992',
#     'Comments': 'MCJ9',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '649067.7578125',
#     'Shape__Length': '5377.07408400393',
#     'rank': 0.057308756},
#    {'_id': 1795,
#     'OBJECTID': '1795',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'KRR',
#     'Fire Name': 'REFUGE',
#     'Local Incident Number': '01918282',
#     'Alarm Date': '5/7/2019 12:00:00 AM',
#     'Containment Date': '5/9/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '3283.456',
#     'Comments': 'L807.  DIGITIZED FROM DIGITALGLOBE (MAXAR) IMAGERY.',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '20195636.421875',
#     'Shape__Length': '29450.8226713625',
#     'rank': 0.057308756},
#    {'_id': 1796,
#     'OBJECTID': '1796',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'LUR',
#     'Fire Name': 'REFUGE',
#     'Local Incident Number': '00000725',
#     'Alarm Date': '7/21/2019 12:00:00 AM',
#     'Containment Date': '7/21/2019 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '158.8546',
#     'Comments': 'MG3K',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '1016954.6171875',
#     'Shape__Length': '4567.6361197367',
#     'rank': 0.057308756},
#    {'_id': 1797,
#     'OBJECTID': '1797',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'FWR',
#     'Fire Name': 'TRESTLE',
#     'Local Incident Number': '00000373',
#     'Alarm Date': '6/2/2019 12:00:00 AM',
#     'Containment Date': '6/2/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.548332',
#     'Comments': 'L90C.  ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '3533.00390625',
#     'Shape__Length': '360.165721311754',
#     'rank': 0.057308756},
#    {'_id': 1798,
#     'OBJECTID': '1798',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'SPR',
#     'Fire Name': 'SEARS',
#     'Local Incident Number': '00018910',
#     'Alarm Date': '10/17/2019 12:00:00 AM',
#     'Containment Date': '10/17/2019 12:00:00 AM',
#     'Cause': '10',
#     'Collection Method': '1',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.98405',
#     'Comments': 'MV0M.  ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '13002.17578125',
#     'Shape__Length': '1382.62041215867',
#     'rank': 0.057308756},
#    {'_id': 1799,
#     'OBJECTID': '1799',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'DLR',
#     'Fire Name': 'DELEVAN T28',
#     'Local Incident Number': '00000369',
#     'Alarm Date': '8/5/2019 12:00:00 AM',
#     'Containment Date': '8/6/2019 12:00:00 AM',
#     'Cause': '2',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '1.919023',
#     'Comments': 'MZW9.  ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '12986.00390625',
#     'Shape__Length': '427.209364318796',
#     'rank': 0.057308756},
#    {'_id': 1800,
#     'OBJECTID': '1800',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'SRR',
#     'Fire Name': 'DRUMHELLER SLOUGH',
#     'Local Incident Number': '00000286',
#     'Alarm Date': '7/2/2019 12:00:00 AM',
#     'Containment Date': '7/2/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '4.376543',
#     'Comments': 'MC50.  ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '29713.96875',
#     'Shape__Length': '1199.41981354364',
#     'rank': 0.057308756},
#    {'_id': 1801,
#     'OBJECTID': '1801',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'FWS',
#     'Unit ID': 'MDR',
#     'Fire Name': 'HEADQUARTERS',
#     'Local Incident Number': '00000444',
#     'Alarm Date': '7/17/2019 12:00:00 AM',
#     'Containment Date': '7/19/2019 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '34.12664',
#     'Comments': 'MF29.  ',
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '245977.19140625',
#     'Shape__Length': '2345.82338677652',
#     'rank': 0.057308756},
#    {'_id': 1802,
#     'OBJECTID': '1802',
#     'Year': '2019',
#     'State': 'CA',
#     'Agency': 'USF',
#     'Unit ID': 'MDF',
#     'Fire Name': 'TUCKER',
#     'Local Incident Number': '00000509',
#     'Alarm Date': '7/28/2019 12:00:00 AM',
#     'Containment Date': '9/16/2019 12:00:00 AM',
#     'Cause': '9',
#     'Collection Method': '4',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '14142.41',
#     'Comments': 'MH73.  ',
#     'Complex Name': None,
#     'IRWIN ID': '{1DAFC388-98C2-401A-849E-C435E3260425}',
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '103073147.164063',
#     'Shape__Length': '79831.9830034312',
#     'rank': 0.057308756},
#    {'_id': 2019,
#     'OBJECTID': '2019',
#     'Year': '2018',
#     'State': 'CA',
#     'Agency': 'CCO',
#     'Unit ID': 'ORC',
#     'Fire Name': 'EL TORO IC ',
#     'Local Incident Number': '18009721',
#     'Alarm Date': '1/24/2018 12:00:00 AM',
#     'Containment Date': '1/24/2018 12:00:00 AM',
#     'Cause': '14',
#     'Collection Method': '6',
#     'Management Objective': '1',
#     'GIS Calculated Acres': '0.09832976',
#     'Comments': None,
#     'Complex Name': None,
#     'IRWIN ID': None,
#     'Fire Number (historical use)': None,
#     'Complex ID': None,
#     'DECADES': '2010',
#     'Shape__Area': '575.63671875',
#     'Shape__Length': '160.241794730047',
#     'rank': 0.057308756}],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'OBJECTID', 'type': 'text'},
#    {'id': 'Year', 'type': 'text'},
#    {'id': 'State', 'type': 'text'},
#    {'id': 'Agency', 'type': 'text'},
#    {'id': 'Unit ID', 'type': 'text'},
#    {'id': 'Fire Name', 'type': 'text'},
#    {'id': 'Local Incident Number', 'type': 'text'},
#    {'id': 'Alarm Date', 'type': 'text'},
#    {'id': 'Containment Date', 'type': 'text'},
#    {'id': 'Cause', 'type': 'text'},
#    {'id': 'Collection Method', 'type': 'text'},
#    {'id': 'Management Objective', 'type': 'text'},
#    {'id': 'GIS Calculated Acres', 'type': 'text'},
#    {'id': 'Comments', 'type': 'text'},
#    {'id': 'Complex Name', 'type': 'text'},
#    {'id': 'IRWIN ID', 'type': 'text'},
#    {'id': 'Fire Number (historical use)', 'type': 'text'},
#    {'id': 'Complex ID', 'type': 'text'},
#    {'id': 'DECADES', 'type': 'text'},
#    {'id': 'Shape__Area', 'type': 'text'},
#    {'id': 'Shape__Length', 'type': 'text'},
#    {'id': 'rank', 'type': 'float'}],
#   '_links': {'start': '/api/3/action/datastore_search?limit=1000&q=2019&resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991',
#    'next': '/api/3/action/datastore_search?limit=1000&q=2019&resource_id=d73ee828-c2c6-485c-91dc-c26bd9ce3991&offset=1000'},
#   'total': 320,
#   'total_was_estimated': False}}

# %%
df = pd.DataFrame(response['result']['records'])
df_2019 = df.loc[df['Year'] == f'{str(year)}']
columns_to_keep = ['Year', 'Alarm Date','Containment Date','Cause','GIS Calculated Acres']
columns_to_drop = [col for col in df_2019.columns if col not in columns_to_keep]
df_2019 = df_2019.drop(columns=columns_to_drop)
df_2019 = df_2019.dropna (subset = ["Containment Date"])
df_2019.head()
# Out:
#    Year              Alarm Date        Containment Date Cause  \
# 1  2019  11/15/2019 12:00:00 AM  11/15/2019 12:00:00 AM    14
# 2  2019   5/29/0219 12:00:00 AM   5/29/0219 12:00:00 AM    16
# 3  2019   7/31/2019 12:00:00 AM   7/31/2019 12:00:00 AM    14
# 4  2019  10/31/2019 12:00:00 AM   11/5/2019 12:00:00 AM    14
# 5  2019  10/30/2019 12:00:00 AM  11/13/2019 12:00:00 AM    14
#
#   GIS Calculated Acres
# 1             14.53588
# 2              2.29694
# 3              3.76396
# 4             10042.46
# 5             1806.234

# %%
df_2019['Alarm Date'] = [dt.replace(' 12:00:00 AM', '') for dt in df_2019['Alarm Date']]
df_2019['Containment Date'] = [str(item) for item in df_2019['Containment Date']]
df_2019['Containment Date'] = [dt.replace(' 12:00:00 AM', '') for dt in df_2019['Containment Date']]
df_2019.head()
# Out:
#    Year  Alarm Date Containment Date Cause GIS Calculated Acres
# 1  2019  11/15/2019       11/15/2019    14             14.53588
# 2  2019   5/29/0219        5/29/0219    16              2.29694
# 3  2019   7/31/2019        7/31/2019    14              3.76396
# 4  2019  10/31/2019        11/5/2019    14             10042.46
# 5  2019  10/30/2019       11/13/2019    14             1806.234

# %%
df_2019 = df_2019.rename(columns={'Cause': 'Cause #'})
df_2019['Cause'] = ''
df_2019['Cause #'] = df_2019['Cause #'].astype(int)
def map_cause_to_meaning(i):
    if i == 1:
        return 'Lightning'
    elif i == 2:
        return 'Equipment Use'
    elif i == 3:
        return 'Smoking'
    elif i == 4:
        return 'Campfire'
    elif i == 5:
        return 'Debris'
    elif i == 6:
        return 'Railroad'
    elif i == 7:
        return 'Arson'
    elif i == 8:
        return 'Playing with fire'
    elif i == 9:
        return 'Miscellaneous'
    elif i == 10:
        return 'Vehicle'
    elif i == 11:
        return 'Powerline'
    elif i == 12:
        return 'Firefighter Training'
    elif i == 13:
        return 'Non-Firefighter Training'
    elif i == 14:
        return 'Unknown / Unidentified'
    elif i == 15:
        return 'Structure'
    elif i == 16:
        return 'Aircraft'
    elif i == 18:
        return 'Escaped Prescribed Burn'
    elif i == 19:
        return 'Illegal Alien Campfire'
    else:
        return 'N/A'
df_2019['Cause'] = df_2019['Cause #'].apply(map_cause_to_meaning)
df_2019.head()
# Out:
#    Year  Alarm Date Containment Date  Cause # GIS Calculated Acres  \
# 1  2019  11/15/2019       11/15/2019       14             14.53588
# 2  2019   5/29/0219        5/29/0219       16              2.29694
# 3  2019   7/31/2019        7/31/2019       14              3.76396
# 4  2019  10/31/2019        11/5/2019       14             10042.46
# 5  2019  10/30/2019       11/13/2019       14             1806.234
#
#                     Cause
# 1  Unknown / Unidentified
# 2                Aircraft
# 3  Unknown / Unidentified
# 4  Unknown / Unidentified
# 5  Unknown / Unidentified

# %%
df_2019.to_csv("outputs/fires_2019.csv",
                  encoding="utf-8", index=False, header=True)

# %%
# Attempt to convert 'Alarm Date' to datetime, coercing errors
df_2019['Alarm Date'] = pd.to_datetime(df_2019['Alarm Date'], errors='coerce')

# Display rows with invalid dates
invalid_dates = df_2019[df_2019['Alarm Date'].isna()]
print(invalid_dates)

# Drop rows where 'Alarm Date' is in 2017
df_2019 = df_2019[df_2019['Alarm Date'].dt.year != 2017]

# Continue with the processing
df_byalarm = df_2019.sort_values(by='Alarm Date').reset_index()
df_byalarm.head()
# Out:
#    Year Alarm Date Containment Date  Cause # GIS Calculated Acres     Cause
# 2  2019        NaT        5/29/0219       16              2.29694  Aircraft
#    index  Year Alarm Date Containment Date  Cause # GIS Calculated Acres  \
# 0    216  2019 2019-03-13        3/16/2019       14             30.28639
# 1    262  2019 2019-03-14         4/1/2019        1             22.74746
# 2    132  2019 2019-03-15        3/20/2019        7             564.2154
# 3    191  2019 2019-04-18        4/18/2019       10             1.908545
# 4     79  2019 2019-04-20        4/20/2019        9             44.81123
#
#                     Cause
# 0  Unknown / Unidentified
# 1               Lightning
# 2                   Arson
# 3                 Vehicle
# 4           Miscellaneous

# %%
earliest_fire = df_byalarm['Alarm Date'][0]
earliest_fire
# Out:
# Timestamp('2019-03-13 00:00:00')

# %%
# Convert 'Containment Date' to datetime, coercing errors
df_2019['Containment Date'] = pd.to_datetime(df_2019['Containment Date'], errors='coerce')

# Drop rows with invalid 'Containment Date'
df_2019_filtered = df_2019.dropna(subset=['Containment Date'])

# Now you can sort and process the DataFrame as needed
df_bycontainment = df_2019_filtered.sort_values(by='Containment Date', ascending=False).reset_index(drop=True)
latest_containment = df_bycontainment['Containment Date'].iloc[0]

df_bycontainment.head()
# Out:
#    Year Alarm Date Containment Date  Cause # GIS Calculated Acres  \
# 0  2019 2019-10-27       2020-01-28        9             703.3557
# 1  2019 2019-07-27       2020-01-27        9             110.7408
# 2  2019 2019-09-04       2020-01-15        9              54614.9
# 3  2019 2019-12-19       2019-12-19        5             12.63458
# 4  2019 2019-07-26       2019-12-18        1             6614.634
#
#            Cause
# 0  Miscellaneous
# 1  Miscellaneous
# 2  Miscellaneous
# 3         Debris
# 4      Lightning

# %%
latest_containment
# Out:
# Timestamp('2020-01-28 00:00:00')

# %%
output_path = os.path.join("outputs", "timeline_dates_2019.csv")
with open(output_path, 'w') as csvfile:

    # Initialize csv.writer
    csvwriter = csv.writer(csvfile, delimiter=',')

    # Write the first row (column headers)
    csvwriter.writerow(['Title', 'Date'])
    csvwriter.writerow(['Earliest Fire', earliest_fire])

    # Write the second row
    csvwriter.writerow(['Latest Containment', latest_containment])
