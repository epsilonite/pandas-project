# %%
# Dependencies
import requests
import pandas as pd
import time
from api_key import noaa_key

# %%
df = pd.read_csv('outputs/prcp/CA_stns.csv')
df.head(3)
# Out:
#        station
# 0  US1CAAL0001
# 1  US1CAAL0003
# 2  US1CAAL0004

# %%
year = 2023
dts = pd.date_range(str(year) + "-01-01", str(year) + "-12-31", freq="D")

# %%
for dt in dts:
    d = str(dt.date())
    dt_df = pd.read_csv(f'outputs/prcp/2023dt/{d}.csv')
    df = df.merge(dt_df, on='station', how='outer')

# %%
df
# Out:
#           station  2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  \
# 0     US1CAAL0001        69.6         0.0        11.2         6.4        45.5
# 1     US1CAAL0003        82.3         0.0        11.2         5.8        22.6
# 2     US1CAAL0004        81.0         0.0        13.0         5.1        27.2
# 3     US1CAAL0006        54.6         NaN         9.7         NaN        46.2
# 4     US1CAAL0011         NaN         NaN         7.1        23.6         NaN
# ...           ...         ...         ...         ...         ...         ...
# 1129  USW00093241         0.0        17.5         0.0        40.4        15.2
# 1130  USW00093242         0.3         3.6         0.0         2.5         4.6
# 1131  USW00093243         0.2         7.7         0.0         9.4        11.5
# 1132  USW00093245         0.0         8.9         0.0        43.3         9.7
# 1133  USW00094299         0.0         2.5         0.0         0.5         6.6
#
# ...

# %%
fill_df = df.fillna(0.0)
fill_df.to_csv('outputs/prcp/CA_prcp_stn.csv',index=False)
